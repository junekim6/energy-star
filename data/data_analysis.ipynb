# %% [markdown]
# ### Notebook Setup

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('ggplot2')
# require('readr')
# require('extrafont')
# require('dplyr')
# require('reshape2')
# # require('theme538')
# Out:
# R[write to console]: Loading required package: ggplot2
# R[write to console]: Loading required package: readr
#
# R[write to console]: Loading required package: extrafont
#
# R[write to console]: Registering fonts with R
#
# R[write to console]: Loading required package: dplyr
#
# R[write to console]:
# Attaching package: ‘dplyr’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# R[write to console]: Loading required package: reshape2

# %%
# set maximum number of columns to display
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Refrigerator Analysis

# %%
epa_ref = pd.read_csv('epa_residential_refrigerators.csv')
epa_freeze =  pd.read_csv('epa_residential_freezers.csv')
doe_ref = pd.read_csv('doe-refrigerator.csv')

# %%
epa_ref_freeze = pd.concat([epa_ref, epa_freeze])
# epa_ref_freeze.to_csv('epa_refrigerator_freezer_combined.csv', index=False)

# %%
# Analyze energy efficiency of refrigerators and freezers by brand.

epa_ref_freeze.head()
# Out:
#    ENERGY STAR Unique ID   Brand Name Model Number  \
# 0                2369304  Arctic Wind    2ATMW212E
# 1                2397747  Arctic Wind    2AW1BF26A
# 2                2393669  Arctic Wind   2AW1SLF44A
# 3                2370277  Arctic Wind     ABM*171E
# 4                2370276  Arctic Wind    ABM*171E*
#
#                         Additional Model Information  \
# 0                                                NaN
# 1                                       ,2AW1SLF26A,
# 2                                                NaN
# 3  ,,The symbol *, maybe replaced by A-Z, means d...
# 4  ,,The symbol *, maybe replaced by A-Z, means d...
#
#                          UPC                  Type  \
# 0                        NaN           Top Freezer
# 1  850012484240;850012484370  Compact Refrigerator
# 2               850012484400  Compact Refrigerator
# 3                        NaN        Bottom Freezer
# 4                        NaN        Bottom Freezer
#
#                                        Product Class Defrost Type Compact  \
# 0  3 - Refrigerator-freezers - automatic defrost ...    Automatic      No
# 1    11A - Compact All-Refrigerator - manual defrost       Manual     Yes
# 2    11A - Compact All-Refrigerator - manual defrost       Manual     Yes
# 3  5 - Refrigerator-freezers - automatic defrost ...    Automatic      No
# 4  5 - Refrigerator-freezers - automatic defrost ...    Automatic      No
#
#   Built-in Thru the Door Dispenser Ice Maker Counter Depth  Height (in)  \
# 0       No                      No        No            No         67.0
# 1       No                      No        No            No         27.4
# 2       No                      No        No            No         33.1
# 3       No                      No        No            No         69.1
# 4       No                      No        No            No         69.1
#
#    Width (in)  Capacity (Total Volume) (ft3)  Adjusted Volume (ft3)  \
# 0        33.0                           21.0                   25.6
# 1        17.5                            2.6                    2.6
# 2        18.7                            4.4                    4.4
# 3        31.3                           17.1                   20.9
# 4        31.3                           17.1                   20.9
#
#    Annual Energy Use (kWh/yr)  US Federal Standard (kWh/yr)  \
# 0                         396                         440.0
# 1                         215                         239.0
# 2                         228                         254.0
# 3                         451                         502.0
# 4                         451                         502.0
#
#    Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 0                                              10.0              NaN
# 1                                              10.0              NaN
# 2                                              10.0              NaN
# 3                                              10.0           R-600a
# 4                                              10.0           R-600a
#
#          Refrigerant with GWP Connected Functionality Connects Using  \
# 0                         NaN                      No            NaN
# 1                         NaN                      No            NaN
# 2                         NaN                      No            NaN
# 3  R-600a (GWP:3 | Lower GWP)                      No            NaN
# 4  R-600a (GWP:3 | Lower GWP)                      No            NaN
#
#   Connected Functionality Tested Communication Standard Application Layer  \
# 0                            NaN                                      NaN
# 1                            NaN                                      NaN
# 2                            NaN                                      NaN
# 3                            NaN                                      NaN
# 4                            NaN                                      NaN
#
#   Direct on-premises Open-standard Based Interconnection  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Date Available On Market Date Certified                Markets  \
# 0               10/30/2020     11/09/2020  United States, Canada
# 1               08/15/2022     06/23/2022  United States, Canada
# 2               04/15/2022     03/08/2022  United States, Canada
# 3               11/23/2020     11/25/2020  United States, Canada
# 4               11/23/2020     11/25/2020  United States, Canada
#
#                             CB Model Identifier  \
# 0   ES_1121980_2ATMW212E_11102020012636_1596636
# 1   ES_1121980_2AW1BF26A_06202022134236_2692056
# 2  ES_1121980_2AW1SLF44A_03012022142251_5311380
# 3   ES_1121980_ABM*171E_112520200126738_9572853
# 4   ES_1121980_ABM*171E*_11252020012627_7795251
#
#   Meets ENERGY STAR Most Efficient 2023 Criteria
# 0                                            Yes
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No

# %%
epa_ref_freeze['energy_per_volume'] = epa_ref_freeze['Annual Energy Use (kWh/yr)'] / epa_ref_freeze['Adjusted Volume (ft3)']

# %%
# calculate the average energy efficiency of each brand
least_efficient = epa_ref_freeze.groupby('Brand Name')['energy_per_volume'].mean().sort_values(ascending=False).reset_index().head(10)
most_efficienct = epa_ref_freeze.groupby('Brand Name')['energy_per_volume'].mean().sort_values(ascending=True).reset_index().head(10)

least_efficient.to_csv('least_efficient.csv', index=False)
most_efficienct.to_csv('most_efficienct.csv', index=False)

# %%
least_efficient
# Out:
#                 Brand Name  energy_per_volume
# 0                  ECOFLOW         186.923077
# 1                 Mini Bar         156.871795
# 2       White-Westinghouse         129.375000
# 3                  RVISION         111.149733
# 4  Danby or Danby Designer         103.929924
# 5                    Willz         103.225806
# 6                  DOMETIC         102.889321
# 7                    IGLOO         100.355240
# 8           Antarctic Star          99.218750
# 9                   Lorell          98.402778

# %%
most_efficienct
# Out:
#                                           Brand Name  energy_per_volume
# 0                                               Asko           9.599462
# 1                                            Gallery          14.264577
# 2                                             Elisii          15.330535
# 3                                                CTM          16.086957
# 4                                              ALPHA          16.147541
# 5                                             SANKEY          16.272111
# 6                                          Gladiator          16.460674
# 7  Danby or Danby Designer or Danby Premiere or S...          16.466667
# 8                                     Danby Premiere          16.466667
# 9                                        Conservator          16.705643

# %%
# Find all models from the EPA are in the DOE, using REGEX

def regexify_model_number(model_number):
    model_number_regex = re.sub(r'\*', '.', model_number)
    model_number_regex = re.sub(r'\#', '.', model_number_regex)
    return model_number_regex

epa_ref_freeze['model_number_modified'] = epa_ref_freeze['Model Number'].apply(regexify_model_number)
doe_ref['individual_model_number_modified'] = doe_ref['Individual_Model_Number_Covered_by_Basic_Model_m'].apply(regexify_model_number)

# %%
def find_epa_model_number_in_doe_database(model_number):
    return doe_ref['individual_model_number_modified'].str.contains(model_number, regex=True).any()

# %%
epa_models_in_doe_database = epa_ref_freeze[epa_ref_freeze.model_number_modified.apply(find_epa_model_number_in_doe_database)]
epa_models_in_doe_database.head()
# epa_models_in_doe_database.to_csv('epa_ref_freezer_models_in_doe_database.csv', index=False)
# Out:
#     ENERGY STAR Unique ID Brand Name Model Number  \
# 19                2354266     Avanti      AR17T0W
# 20                2309224     Avanti      AR17T1B
# 21                2216363     Avanti      AR2406W
# 22                2303594     Avanti      AR24T3S
# 23                2353672     Avanti      AR24T3S
#
#    Additional Model Information  UPC                  Type  \
# 19         ,AR17T1B,; ,AR17T3S,  NaN  Compact Refrigerator
# 20         ,AR17T0W,; ,AR17T3S,  NaN  Compact Refrigerator
# 21                    ,AR2416B,  NaN  Compact Refrigerator
# 22                          NaN  NaN  Compact Refrigerator
# 23                          NaN  NaN  Compact Refrigerator
#
#                                         Product Class Defrost Type Compact  \
# 19  13A - Compact All-Refrigerators - automatic de...    Automatic     Yes
# 20  13A - Compact All-Refrigerators - automatic de...    Automatic     Yes
# 21  13A - Compact All-Refrigerators - automatic de...    Automatic     Yes
# 22  13A - Compact All-Refrigerators - automatic de...    Automatic     Yes
# 23  13A - Compact All-Refrigerators - automatic de...    Automatic     Yes
#
#    Built-in Thru the Door Dispenser Ice Maker Counter Depth  Height (in)  \
# 19       No                      No        No            No         20.2
# 20       No                      No        No            No         20.1
# 21       No                      No        No            No         25.0
# 22       No                      No        No            No         24.9
# 23       No                      No        No            No         24.8
#
#     Width (in)  Capacity (Total Volume) (ft3)  Adjusted Volume (ft3)  \
# 19        17.7                            1.7                    1.7
# 20        17.7                            1.7                    1.7
# 21        18.5                            2.2                    2.2
# 22        18.5                            2.4                    2.4
# 23        17.7                            2.4                    2.4
#
#     Annual Energy Use (kWh/yr)  US Federal Standard (kWh/yr)  \
# 19                         233                         275.0
# 20                         238                         275.0
# 21                         230                         279.0
# 22                         238                         281.0
# 23                         238                         281.0
#
#     Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 19                                              15.0              NaN
# 20                                              13.0              NaN
# 21                                              18.0              NaN
# 22                                              15.0              NaN
# 23                                              15.0              NaN
#
#    Refrigerant with GWP Connected Functionality Connects Using  \
# 19                  NaN                      No            NaN
# 20                  NaN                      No            NaN
# 21                  NaN                      No            NaN
# 22                  NaN                      No            NaN
# 23                  NaN                      No            NaN
#
#    Connected Functionality Tested Communication Standard Application Layer  \
# 19                            NaN                                      NaN
# 20                            NaN                                      NaN
# 21                            NaN                                      NaN
# 22                            NaN                                      NaN
# 23                            NaN                                      NaN
#
#    Direct on-premises Open-standard Based Interconnection  \
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#    Date Available On Market Date Certified                Markets  \
# 19               01/01/2020     01/30/2020          United States
# 20               11/15/2017     01/16/2018  United States, Canada
# 21               07/21/2014     07/22/2014          United States
# 22               09/01/2017     09/14/2017          United States
# 23               01/01/2020     01/16/2020          United States
#
#                         CB Model Identifier  \
# 19  ES_92257_AR17T1B_01102020102044_8042261
# 20  ES_92257_AR17T1B_11232017092331_4355584
# 21  ES_92257_AR2406W_07212014164849_4965174
# 22  ES_92257_AR24T3S_09122017132724_1491662
# 23  ES_92257_AR24T3S_01102020153313_9034234
#
#    Meets ENERGY STAR Most Efficient 2023 Criteria model_number_modified
# 19                                             No               AR17T0W
# 20                                             No               AR17T1B
# 21                                             No               AR2406W
# 22                                             No               AR24T3S
# 23                                             No               AR24T3S

# %%
epa_models_not_in_doe_database = epa_ref_freeze[~epa_ref_freeze.model_number_modified.apply(find_epa_model_number_in_doe_database)]
# epa_models_not_in_doe_database.to_csv('epa_ref_freezer_models_not_in_doe_database.csv', index=False)

# %%
def find_doe_models_in_energy_star(model_number):
    return epa_ref_freeze['model_number_modified'].str.contains(model_number, regex=True).any()

# DOE models that appear in EPA ENERGY STAR dataset
doe_ref_energy_star = doe_ref[doe_ref.individual_model_number_modified.apply(find_doe_models_in_energy_star)]

# DOE models that do not appear in EPA ENERGY STAR dataset
doe_ref_non_energy_star = doe_ref[~doe_ref.individual_model_number_modified.apply(find_doe_models_in_energy_star)]

# %%
# doe_ref_energy_star.to_csv('doe_models_in_energy_star_database.csv', index=False)
# doe_ref_non_energy_star.to_csv('doe_models_not_in_energy_star_database.csv', index=False)

# %% [markdown]
# # TV Analysis

# %%
tv_epa = pd.read_csv('epa-tv.csv')
tv_doe = pd.read_csv('doe-tv.csv')

# %%
tv_epa.head()
# Out:
#    ENERGY STAR Unique ID                         ENERGY STAR Partner  \
# 0                2405713  Top Victory Electronics (Taiwan) Co., Ltd.
# 1                2405721  Top Victory Electronics (Taiwan) Co., Ltd.
# 2                2401931  Top Victory Electronics (Taiwan) Co., Ltd.
# 3                2404180  Top Victory Electronics (Taiwan) Co., Ltd.
# 4                2407358                 Xitrix Computer Corporation
#
#   Brand Name     Model Name   Model Number Additional Model Information  \
# 0    PHILIPS  50HFL4518U/27  50HFL4518U/27                          NaN
# 1    PHILIPS  55HFL4518U/27  55HFL4518U/27                          NaN
# 2    PHILIPS  55HFL5214U/27  55HFL5214U/27   55BFL2214/27,55BFL2214/27,
# 3    PHILIPS  65HFL5214U/27  65HFL5214U/27   ,65BFL2214/27,65BFL2214/27
# 4     XITRIX    XPN-DSA3250    XPN-DSA3250                          NaN
#
#                          UPC     Product Type Application Display Type  \
# 0               871886300399  Television (TV)    Consumer          LCD
# 1               871886300405  Television (TV)    Consumer          LCD
# 2  871886300214;871886300276  Television (TV)    Consumer          LCD
# 3  871886300221;871886300283  Television (TV)    Consumer          LCD
# 4                        NaN  Television (TV)    Consumer          LCD
#
#   Backlight Technology Type  Diagonal Viewable Screen Size (in.)  \
# 0            Direct-lit LED                                 49.5
# 1            Direct-lit LED                                 54.6
# 2            Direct-lit LED                                 54.5
# 3            Direct-lit LED                                 64.5
# 4            Direct-lit LED                                 32.0
#
#    Screen Area (sq. in.)  Native Horizontal Resolution (pixels)  \
# 0                1047.00                                   3840
# 1                1275.70                                   3840
# 2                1275.70                                   3840
# 3                1779.10                                   3840
# 4                 424.18                                    768
#
#    Native Vertical Resolution (pixels) Resolution Format  \
# 0                                 2160          4K (UHD)
# 1                                 2160          4K (UHD)
# 2                                 2160          4K (UHD)
# 3                                 2160          4K (UHD)
# 4                                 1366             Other
#
#   High Contrast Ratio (HCR) Display          Physical Data Ports Available  \
# 0                                No        Universal Serial Bus (USB),HDMI
# 1                                No        Universal Serial Bus (USB),HDMI
# 2                                No        Universal Serial Bus (USB),HDMI
# 3                                No        Universal Serial Bus (USB),HDMI
# 4                                No  Universal Serial Bus (USB),Other,HDMI
#
#                                   Ethernet Supported  \
# 0  Gigabit Ethernet (1000 Mbit/s),Gigabit Energy ...
# 1  Gigabit Ethernet (1000 Mbit/s),Gigabit Energy ...
# 2                     Gigabit Ethernet (1000 Mbit/s)
# 3                     Gigabit Ethernet (1000 Mbit/s)
# 4                                               None
#
#   Low Power Wireless Technologies Supported  \
# 0                                      None
# 1                                      None
# 2                                      None
# 3                                      None
# 4                                      None
#
#                                             Features  \
# 0  High Dynamic Range Upscaling,Full Network Conn...
# 1  High Dynamic Range Upscaling,Full Network Conn...
# 2                                               None
# 3                                               None
# 4                                               None
#
#   Automatic Brightness Control  \
# 0                           No
# 1                           No
# 2                           No
# 3                           No
# 4                           No
#
#   Is Automatic Brightness Control Enabled by Default in the Default SDR Preset Picture Setting When Television is Shipped?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Average On Mode Power Consumption for Certification (watts)  \
# 0                                              66.90
# 1                                              93.20
# 2                                              83.23
# 3                                             126.80
# 4                                              34.40
#
#    Maximum Average On Mode Power for Certification (watts)  \
# 0                                              71.41
# 1                                              94.11
# 2                                              93.08
# 3                                             129.13
# 4                                              42.80
#
#    Reported On Mode Power (per the Federal Test Procedure) (watts)  \
# 0                                               66.9
# 1                                               93.2
# 2                                               90.8
# 3                                              126.8
# 4                                               34.4
#
#    Reported Annual Energy Consumption (kWh)  \
# 0                                    114.15
# 1                                    150.27
# 2                                    129.76
# 3                                    159.42
# 4                                     64.37
#
#    Power Consumption in Standby Mode when Not Connected to a Network (watts)  \
# 0                                               0.35
# 1                                               0.40
# 2                                               0.40
# 3                                               0.43
# 4                                               0.22
#
#    Power Consumption in Standby Mode when Connected to a Network (watts)  \
# 0                                               0.47
# 1                                               0.51
# 2                                               0.79
# 3                                               0.83
# 4                                               0.22
#
#    Reported Standby-Active, Low Mode Power (watts) Date Available On Market  \
# 0                                             0.47               11/15/2021
# 1                                             0.51               11/18/2022
# 2                                             0.79               12/20/2021
# 3                                             0.83               12/21/2021
# 4                                             0.22               01/05/2023
#
#   Date Certified                Markets  \
# 0     11/21/2022          United States
# 1     11/23/2022          United States
# 2     09/19/2022          United States
# 3     10/20/2022          United States
# 4     01/26/2023  United States, Canada
#
#                                  CB Model Identifier
# 0  ES_1065104_50HFL4518U/27_11212022142452I59_734...
# 1  ES_1065104_55HFL4518U/27_1123202292455I14_7349927
# 2  ES_1065104_55HFL5214U/27_09192022122420I33_734...
# 3  ES_1065104_65HFL5214U/27_1020202214246I20_7349927
# 4      ES_1058575_XPN-DSA3250_01162023112847_6901971

# %%
# Show number of rows in tv_epa and tv_doe
len(tv_epa)
# Out:
# 45

# %%
tv_doe.head()
# Out:
#   Brand_Name_s__s        Individual_Model_Number_m  \
# 0         Hisense                           75U78H
# 1         Hisense    75U7H+(+=0-9 or A-Z or Blank)
# 2         Hisense   75U7+H+(+=0-9 or A-Z or Blank)
# 3         Hisense  85A6+H++(+=0-9 or A-Z or Blank)
# 4         Hisense    85A7G+(+=0-9 or A-Z or Blank)
#
#    Screen_Size__diagonal_in_inches__d  Power_Consumed_in_On_Mode__watts__d  \
# 0                                75.0                                178.0
# 1                                75.0                                178.0
# 2                                75.0                                178.0
# 3                                85.0                                241.0
# 4                                85.0                                241.0
#
#    Power_Consumed_in_Standby_Passive_Mode__watts__d  \
# 0                                               0.3
# 1                                               0.3
# 2                                               0.3
# 3                                               0.3
# 4                                               0.3
#
#    Power_Consumed_in_Standby_Active__Low_Mode__watts___if_applicable__d  \
# 0                                                0.4
# 1                                                0.4
# 2                                                0.4
# 3                                                0.3
# 4                                                0.3
#
#    Power_Consumed_in_Off_Mode__watts___if_applicable__d  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Annual_Energy_Consumption__kWh_per_year__d  \
# 0                                       327.0
# 1                                       327.0
# 2                                       327.0
# 3                                       441.0
# 4                                       441.0
#
#               Link_to_FTC_EnergyGuide_Label_s  \
# 0  https://www.hisense-usa.com/support/models
# 1  https://www.hisense-usa.com/support/models
# 2  https://www.hisense-usa.com/support/models
# 3  https://www.hisense-usa.com/support/models
# 4  https://www.hisense-usa.com/support/models
#
#   Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No

# %%
len(tv_doe)
# Out:
# 4159

# %%
# Replace all '+' with '.' in the model number
tv_epa['model_number_modified'] = tv_epa['Model Number'].str.replace('+', '.')

# %%
def regexify_model_number(model_number):
    model_number_regex = re.sub(r'\*', '.', model_number)
    model_number_regex = re.sub(r'\#', '.', model_number_regex)
    model_number_regex = model_number_regex.replace('+', '.')
    return model_number_regex

# %%
tv_epa['model_number_modified'] = tv_epa['Model Number'].apply(regexify_model_number)
tv_doe['individual_model_number_modified'] = tv_doe['Individual_Model_Number_m'].apply(regexify_model_number)

# %%
# Remove all string between parentheses
tv_doe['individual_model_number_modified'] = tv_doe['individual_model_number_modified'].str.replace(r"\(.*\)","")

# %%
def find_epa_model_number_in_doe_database(model_number):
    return tv_doe['individual_model_number_modified'].str.contains(model_number, regex=True).any()

tv_epa_models_in_doe_database = tv_epa[tv_epa.model_number_modified.apply(find_epa_model_number_in_doe_database)]
len(tv_epa_models_in_doe_database)
tv_epa_models_in_doe_database.to_csv('epa_tv_models_in_doe_database.csv', index=False)

# %%
tv_epa_models_not_in_doe_database = tv_epa[~tv_epa.model_number_modified.apply(find_epa_model_number_in_doe_database)]
tv_epa_models_not_in_doe_database.to_csv('epa_tv_models_not_in_doe_database.csv', index=False)
len(tv_epa_models_not_in_doe_database)
# Out:
# 10

# %%
def find_doe_models_in_energy_star(model_number):
    return tv_epa['model_number_modified'].str.contains(model_number, regex=True).any()

# DOE models that appear in EPA ENERGY STAR dataset
tv_doe_energy_star = tv_doe[tv_doe.individual_model_number_modified.apply(find_doe_models_in_energy_star)]
# tv_doe_energy_star.to_csv('doe_tv_models_in_energy_star_database.csv', index=False)

# DOE models that do not appear in EPA ENERGY STAR dataset
tv_doe_non_energy_star = tv_doe[~tv_doe.individual_model_number_modified.apply(find_doe_models_in_energy_star)]
tv_doe_non_energy_star.to_csv('doe_tv_models_not_in_energy_star_database.csv', index=False)

# %%
print(len(tv_doe_energy_star))
print(len(tv_doe_non_energy_star))
# Out:
# 46
# 4113

# %% [markdown]
# # Residential Clothes washer Analysis

# %%
dishwasher_epa = pd.read_csv("epa_dishwasher.csv")
dishwasher_doe = pd.read_csv("doe_dishwasher.csv")

# %%
dishwasher_epa.head()
# Out:
#    ENERGY STAR Unique ID Brand Name Model Number  \
# 0                2386941      Bosch   SHEM63W5**
# 1                2282867      Bosch   SHEM78W5#*
# 2                2284086      Bosch   SHEM78WH#*
# 3                2338251      Bosch   SHEM78Z5#*
# 4                2338252      Bosch   SHEM78ZH#*
#
#                         Additional Model Information  \
# 0  ,SHEM63W5**,First "*" is for the color, 2nd "*...
# 1  ,SHEM78W5#*,"#" is for the color,  "*" is for ...
# 2                                                NaN
# 3  ,SHEM78Z5#*,1st # - Color Code, 2nd * - Countr...
# 4  ,SHEM78ZH#*,1st # - Color Code, 2nd * - Countr...
#
#                                       UPC      Type  Width (inches)  \
# 0  825225922223;825225922438;825225922445  Standard             NaN
# 1  825225923046;825225923053;825225923060  Standard             NaN
# 2                            825225923954  Standard             NaN
# 3  825225958567;825225958574;825225958581  Standard             NaN
# 4                            825225959434  Standard             NaN
#
#    Depth (inches)  Capacity - Maximum Number of Place Settings  \
# 0             NaN                                          NaN
# 1             NaN                                          NaN
# 2             NaN                                          NaN
# 3             NaN                                          NaN
# 4             NaN                                          NaN
#
#   Soil-Sensing Capability Tub Material Drying Method  \
# 0                     NaN          NaN           NaN
# 1                     NaN          NaN           NaN
# 2                     NaN          NaN           NaN
# 3                     NaN          NaN           NaN
# 4                     NaN          NaN           NaN
#
#   Additional Product Features  Annual Energy Use (kWh/yr)  \
# 0                         NaN                         269
# 1                         NaN                         269
# 2                         NaN                         239
# 3                         NaN                         269
# 4                         NaN                         269
#
#    US Federal Standard (kWh/yr)  % Better than US Federal Standard (kWh/yr)  \
# 0                         307.0                                        12.0
# 1                         307.0                                        12.0
# 2                         307.0                                        22.0
# 3                         307.0                                        12.0
# 4                         307.0                                        12.0
#
#    Water Use (gallons/cycle)  US Federal Standard (gallons/cycle)  \
# 0                        2.9                                  5.0
# 1                        2.9                                  5.0
# 2                        2.9                                  5.0
# 3                        3.5                                  5.0
# 4                        3.5                                  5.0
#
#    % Better than US Federal Standard (gallons/cycle) Connected Capable  \
# 0                                               42.0                No
# 1                                               42.0                No
# 2                                               42.0                No
# 3                                               30.0                No
# 4                                               30.0                No
#
#   Connects Using Communication Hardware Architecture  DR Protocol  \
# 0            NaN                                 NaN          NaN
# 1            NaN                                 NaN          NaN
# 2            NaN                                 NaN          NaN
# 3            NaN                                 NaN          NaN
# 4            NaN                                 NaN          NaN
#
#   Direct on-premises Open-standard Based Interconnection  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Date Available On Market  Date Certified                Markets  \
# 0               11/09/2016      10/26/2021  United States, Canada
# 1               11/09/2016      10/26/2016  United States, Canada
# 2               10/27/2016      11/15/2016  United States, Canada
# 3               05/30/2019      05/15/2019  United States, Canada
# 4               05/30/2019      05/15/2019  United States, Canada
#
#                           CB Model Identifier  \
# 0  ES_31649_SHEM63W5**_10272021101706_1474573
# 1  ES_31649_SHEM78W5#*_10272016211527_9332087
# 2  ES_31649_SHEM78WH#*_10272016142033_5994378
# 3  ES_31649_SHEM78Z5#*_05142019152636_2580377
# 4  ES_31649_SHEM78ZH#*_05142019152636_8975946
#
#   Meets ENERGY STAR Most Efficient 2023 Criteria
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No

# %%
len(dishwasher_epa)
# Out:
# 1060

# %%
dishwasher_doe.head()
# Out:
#   Brand_Name_s__s Product_Group_Code_Description_s Basic_Model_Number_m  \
# 0              LG         Standard size dishwasher            LDP681***
# 1              LG         Standard size dishwasher            LDP679#**
# 2            hOme               Compact dishwasher         WQP6-3601-US
# 3            hOme               Compact dishwasher         WQP6-3601-US
# 4      Farberware               Compact dishwasher         WQP6-3601-US
#
#   Individual_Model_Number_Covered_by_Basic_Model_m  \
# 0                                        LDP681***
# 1                                        LDP679#**
# 2                                    WQP6-3602G-US
# 3                                       HME010393N
# 4                                      FCD06ASWWHC
#
#    Annual_Energy_Use__Kilowatt_Hours_Year__d  \
# 0                                      238.0
# 1                                      238.0
# 2                                      203.0
# 3                                      203.0
# 4                                      203.0
#
#    Water_Consumption__Gallons_Cycle__d  Capacity__Number_of_Place_Settings__d  \
# 0                                  2.9                                   15.0
# 1                                  2.9                                   15.0
# 2                                  3.1                                    6.0
# 3                                  3.1                                    6.0
# 4                                  3.1                                    6.0
#
#   Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#      Link_to_FTC_EnergyGuide_Label_s
# 0  https://www.lg.com/us/dishwashers
# 1  https://www.lg.com/us/dishwashers
# 2              By annual report date
# 3              By annual report date
# 4              By annual report date

# %%
len(dishwasher_doe)
# Out:
# 1269

# %%
dishwasher_epa['model_number_modified'] = dishwasher_epa['Model Number'].apply(regexify_model_number)
dishwasher_doe['individual_model_number_modified'] = dishwasher_doe['Individual_Model_Number_Covered_by_Basic_Model_m'].apply(regexify_model_number)

# %%
# find epa model number in doe database
def find_epa_model_number_in_doe_database(model_number):
    return dishwasher_doe['individual_model_number_modified'].str.contains(model_number, regex=True).any()

dishwasher_epa_models_in_doe_database = dishwasher_epa[dishwasher_epa.model_number_modified.apply(find_epa_model_number_in_doe_database)]
dishwasher_epa_models_in_doe_database.to_csv('epa_dishwasher_models_in_doe_database.csv', index=False)

dishwasher_epa_models_not_in_doe_database = dishwasher_epa[~dishwasher_epa.model_number_modified.apply(find_epa_model_number_in_doe_database)]
dishwasher_epa_models_not_in_doe_database.to_csv('epa_dishwasher_models_not_in_doe_database.csv', index=False)

# %%
print(len(dishwasher_epa_models_in_doe_database))
print(len(dishwasher_epa_models_not_in_doe_database))
# Out:
# 696
# 364

# %%
def find_doe_models_in_energy_star(model_number):
    return dishwasher_epa['model_number_modified'].str.contains(model_number, regex=True).any()

# DOE models that appear in EPA ENERGY STAR dataset
dishwasher_doe_energy_star = dishwasher_doe[dishwasher_doe.individual_model_number_modified.apply(find_doe_models_in_energy_star)]
dishwasher_doe_energy_star.to_csv('doe_dishwasher_models_in_energy_star_database.csv', index=False)

# DOE models that do not appear in EPA ENERGY STAR dataset
dishwasher_doe_non_energy_star = dishwasher_doe[~dishwasher_doe.individual_model_number_modified.apply(find_doe_models_in_energy_star)]
dishwasher_doe_non_energy_star.to_csv('doe_dishwasher_models_not_in_energy_star_database.csv', index=False)

print(len(dishwasher_doe_energy_star))
print(len(dishwasher_doe_non_energy_star))
# Out:
# 1016
# 253

# %% [markdown]
# # Clothes Washer Analysis

# %%
clotheswasher_epa = pd.read_csv("epa_clotheswasher.csv")
clotheswasher_doe = pd.read_csv("doe_clotheswasher.csv")

print(len(clotheswasher_epa))
print(len(clotheswasher_doe))
# Out:
# 344
# 1263

# %%
clotheswasher_epa.head()
# Out:
#    ENERGY STAR Unique ID Brand Name  Model Number  \
# 0                2374994         GE  GTW490BMR***
# 1                2331678         GE  GTW500A*N***
# 2                2370952         GE  GTW500A*N***
# 3                2370953         GE  GTW540A*P***
# 4                2375000         GE  GTW550BMR***
#
#          Additional Model Information           UPC Load Configuration  \
# 0                                 NaN  757638370103           Top Load
# 1  ,GTW500ASNWS,Color: White / Silver  084691845638           Top Load
# 2                       ,GTW500ASNWS,  084691845638           Top Load
# 3                       ,GTW540ASPWS,  084691870944           Top Load
# 4                                 NaN  757638370127           Top Load
#
#   Special Type    Additional Washer Features Intended Market  \
# 0          NaN                  Gentle Cycle     Residential
# 1          NaN    Gentle Cycle,Delayed Start     Residential
# 2          NaN                  Gentle Cycle     Residential
# 3          NaN  Sanitize Option,Gentle Cycle     Residential
# 4          NaN                  Gentle Cycle     Residential
#
#    Volume (cu. ft.)  Height (inches)  Width (inches)  Depth (inches)  \
# 0               4.1              NaN            26.8             NaN
# 1               4.6              NaN            27.0             NaN
# 2               4.6              NaN            27.0             NaN
# 3               4.6              NaN            27.0             NaN
# 4               4.3              NaN            26.8             NaN
#
#    Integrated Modified Energy Factor (IMEF)  US Federal Standard (IMEF)  \
# 0                                      2.06                        1.29
# 1                                      2.06                        1.29
# 2                                      2.06                        1.29
# 3                                      2.06                        1.29
# 4                                      2.08                        1.29
#
#    Annual Energy Use (kWh/yr)  Integrated Water Factor (IWF)  \
# 0                         156                            4.3
# 1                         175                            4.3
# 2                         175                            4.3
# 3                         175                            4.3
# 4                         164                            3.7
#
#    US Federal Standard (IWF)  Annual Water Use (gallons/yr)  \
# 0                        8.4                           5252
# 1                        8.4                           5860
# 2                        8.4                           5860
# 3                        8.4                           5860
# 4                        8.4                           4683
#
#    Drum Capacity for the dryer in a Combination All-in-One Washer-Dryer  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Heat Pump Technology for the dryer in a Combination All-in-One Washer-Dryer  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Combined Energy Factor (CEF) for the dryer in a Combination All-in-One Washer-Dryer  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Estimated Annual Energy Use (kWh/yr) for the dryer in a Combination All-in-One Washer-Dryer  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Estimated Energy Test Cycle Time (min) for the dryer in a Combination All-in-One Washer-Dryer  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Energy Test Cycle Information for the dryer in a Combination All-in-One Washer-Dryer  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Calculated Combined Energy Factor - Max Dryness Setting (lbs/kWh) for the dryer in a Combination All-in-One Washer-Dryer  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Additional Dryer Features for the dryer in a Combination All-in-One Washer-Dryer  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Connected Connects Using Communication Standard Application Layer  \
# 0        No            NaN                                      NaN
# 1        No            NaN                                      NaN
# 2        No            NaN                                      NaN
# 3        No            NaN                                      NaN
# 4        No            NaN                                      NaN
#
#   Direct on-premises Open-standard Based Interconnection  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Paired ENERGY STAR Clothes Dryer Available  \
# 0                                         No
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                         No
#
#   Paired ENERGY STAR Clothes Dryer ENERGY STAR Model Identifier  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Date Available On Market Date Certified                Markets  \
# 0               02/22/2021     02/22/2021                 Canada
# 1               12/17/2018     12/05/2018  United States, Canada
# 2               04/19/2021     12/16/2020  United States, Canada
# 3               12/22/2020     12/16/2020  United States, Canada
# 4               02/22/2021     02/22/2021                 Canada
#
#                       ENERGY STAR Model Identifier  \
# 0    ES_92277_GTW490BMR***_031820210717386_1699983
# 1   ES_1123206_GTW500A*N***_12052018194545_9145154
# 2  ES_1123206_GTW500A*N***_121520200855585_6243535
# 3   ES_1123206_GTW540A*P***_12152020085595_7471356
# 4    ES_92277_GTW550BMR***_031820210717165_7444530
#
#   Meets ENERGY STAR Most Efficient 2023 Criteria
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No

# %%
clotheswasher_doe.head()
# Out:
#   Brand_Name_s__s                   Product_Group_Code_Description_s  \
# 0         Samsung  Top-loading, standard (1.6 ft3 or greater capa...
# 1         Samsung  Top-loading, standard (1.6 ft3 or greater capa...
# 2         Samsung  Front-loading, standard (1.6 ft3 or greater ca...
# 3         Samsung  Front-loading, standard (1.6 ft3 or greater ca...
# 4         Samsung  Front-loading, standard (1.6 ft3 or greater ca...
#
#   Basic_Model_Number_m Individual_Model_Number_Covered_by_Basic_Model_m  \
# 0          WA45T34**A*                                      WA45T34**A*
# 1          WA44A3405A*                                      WA44A3405A*
# 2          WF50A88**A*                                      WF50A88**A*
# 3          WF50A86**A*                                      WF50A86**A*
# 4        WV60A99**A*-L                                    WV60A99**A*-L
#
#    Capacity__Cubic_Feet__d  \
# 0                      4.5
# 1                      4.4
# 2                      5.0
# 3                      5.0
# 4                      5.0
#
#    Integrated_Modified_Energy_Factor__cubic_feet_per_kilowatt_hour_per_cycle__d  \
# 0                                               1.57
# 1                                               1.57
# 2                                               3.10
# 3                                               3.10
# 4                                               2.92
#
#    Integrated_Water_Factor__gallons_per_cycle_per_cubic_foot__d  \
# 0                                                6.5
# 1                                                6.5
# 2                                                2.9
# 3                                                2.9
# 4                                                2.9
#
#    Corrected_Remaining_Moisture_Content_____d  \
# 0                                        39.9
# 1                                        39.7
# 2                                        39.2
# 3                                        29.7
# 4                                        29.7
#
#   Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#                      Link_to_FTC_EnergyGuide_Label_s
# 0  https://images.samsung.com/is/content/samsung/...
# 1  https://images.samsung.com/is/content/samsung/...
# 2  https://images.samsung.com/is/content/samsung/...
# 3  https://images.samsung.com/is/content/samsung/...
# 4  https://images.samsung.com/is/content/samsung/...

# %%
clotheswasher_doe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1263 entries, 0 to 1262
# Data columns (total 11 columns):
#  #   Column                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                      --------------  -----
#  0   Brand_Name_s__s                                                                                                             1263 non-null   object
#  1   Product_Group_Code_Description_s                                                                                            1263 non-null   object
#  2   Basic_Model_Number_m                                                                                                        1263 non-null   object
#  3   Individual_Model_Number_Covered_by_Basic_Model_m                                                                            1262 non-null   object
#  4   Capacity__Cubic_Feet__d                                                                                                     1263 non-null   float64
#  5   Integrated_Modified_Energy_Factor__cubic_feet_per_kilowatt_hour_per_cycle__d                                                1263 non-null   float64
#  6   Integrated_Water_Factor__gallons_per_cycle_per_cubic_foot__d                                                                1263 non-null   float64
#  7   Corrected_Remaining_Moisture_Content_____d                                                                                  1263 non-null   float64
#  8   Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s                         1263 non-null   object
#  9   Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s  1263 non-null   object
#  10  Link_to_FTC_EnergyGuide_Label_s                                                                                             1263 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 108.7+ KB

# %%
clotheswasher_doe['Individual_Model_Number_Covered_by_Basic_Model_m']
# Out:
# 0         WA45T34**A*
# 1         WA44A3405A*
# 2         WF50A88**A*
# 3         WF50A86**A*
# 4       WV60A99**A*-L
#             ...
# 1258     WFTV10733XC*
# 1259       WM98220SX*
# 1260        LW2427***
# 1261           TNQ41W
# 1262       WFW6605M**
# Name: Individual_Model_Number_Covered_by_Basic_Model_m, Length: 1263, dtype: object

# %%
def regexify_model_number(model_number):
    model_number_regex = re.sub(r'\*', '.', str(model_number))
    model_number_regex = re.sub(r'\#', '.', str(model_number_regex))
    return model_number_regex
# 
clotheswasher_epa['model_number_modified'] = clotheswasher_epa['Model Number'].apply(regexify_model_number)
clotheswasher_doe['individual_model_number_modified'] = clotheswasher_doe['Individual_Model_Number_Covered_by_Basic_Model_m'].apply(regexify_model_number)

# %%
# find epa model number in doe database
def find_epa_model_number_in_doe_database(model_number):
    return clotheswasher_doe['individual_model_number_modified'].str.contains(model_number, regex=True).any()

clotheswasher_epa_models_in_doe_database = clotheswasher_epa[clotheswasher_epa.model_number_modified.apply(find_epa_model_number_in_doe_database)]
clotheswasher_epa_models_in_doe_database.to_csv('epa_clotheswasher_models_in_doe_database.csv', index=False)

clotheswasher_epa_models_not_in_doe_database = clotheswasher_epa[~clotheswasher_epa.model_number_modified.apply(find_epa_model_number_in_doe_database)]
clotheswasher_epa_models_not_in_doe_database.to_csv('epa_clotheswasher_models_not_in_doe_database.csv', index=False)

# %%
print(len(clotheswasher_epa_models_in_doe_database))
print(len(clotheswasher_epa_models_not_in_doe_database))
# Out:
# 271
# 73

# %%
# Find doe model number in epa database
def find_doe_models_in_energy_star(model_number):
    return clotheswasher_epa['model_number_modified'].str.contains(model_number, regex=True).any()

# DOE models that appear in EPA ENERGY STAR dataset
clotheswasher_doe_energy_star = clotheswasher_doe[clotheswasher_doe.individual_model_number_modified.apply(find_doe_models_in_energy_star)]
clotheswasher_doe_energy_star.to_csv('doe_clotheswasher_models_in_energy_star_database.csv', index=False)

# DOE models that do not appear in EPA ENERGY STAR dataset
clotheswasher_doe_non_energy_star = clotheswasher_doe[~clotheswasher_doe.individual_model_number_modified.apply(find_doe_models_in_energy_star)]
clotheswasher_doe_non_energy_star.to_csv('doe_clotheswasher_models_not_in_energy_star_database.csv', index=False)

# %%
print(len(clotheswasher_doe_energy_star))
print(len(clotheswasher_doe_non_energy_star))
# Out:
# 452
# 811

# %% [markdown]
# # Room AC Analysis

# %%
room_ac_epa = pd.read_csv('epa_room_ac.csv')
room_ac_doe = pd.read_csv('doe_room_ac.csv')

# %%
print(len(room_ac_epa))
print(len(room_ac_doe))
# Out:
# 1323
# 1943

# %%
room_ac_epa.head()
# Out:
#    ENERGY STAR Unique ID      Brand Name Model Number  \
# 0                2361168  Black + Decker     BWAM6W**
# 1                2361169  Black + Decker     BWAM8W**
# 2                2294271    BLACK DECKER     BWAC08WT
# 3                2294272    BLACK DECKER     BWAC10WT
# 4                2294273    BLACK DECKER     BWAC12WT
#
#   Additional Model Information  UPC  Height (inches)  Width (inches)  \
# 0                          NaN  NaN              NaN             NaN
# 1                          NaN  NaN              NaN             NaN
# 2                          NaN  NaN              NaN             NaN
# 3                          NaN  NaN              NaN             NaN
# 4                          NaN  NaN              NaN             NaN
#
#    Depth (inches)  Weight (lbs)  Cooling Capacity (Btu/hr)  Voltage (volts)  \
# 0             NaN           NaN                       6000              NaN
# 1             NaN           NaN                       8000              NaN
# 2             NaN           NaN                       8000              NaN
# 3             NaN           NaN                      10000              NaN
# 4             NaN           NaN                      12000              NaN
#
#      Type Installation Mounting Type Support Bracket Heating Mode  \
# 0  Window                        NaN             NaN           No
# 1  Window                        NaN             NaN           No
# 2  Window                        NaN             NaN           No
# 3  Window                        NaN             NaN           No
# 4  Window                        NaN             NaN           No
#
#   Casement Window                                      Product Class  \
# 0            None  2. Without reverse cycle, with louvered sides,...
# 1            None  3. Without reverse cycle, with louvered sides,...
# 2            None  3. Without reverse cycle, with louvered sides,...
# 3            None  3. Without reverse cycle, with louvered sides,...
# 4            None  3. Without reverse cycle, with louvered sides,...
#
#   Variable Speed Compressor Low Noise Refrigerant Type Refrigerant with GWP  \
# 0                        No        No              NaN                  NaN
# 1                        No        No              NaN                  NaN
# 2                       NaN        No              NaN                  NaN
# 3                       NaN        No              NaN                  NaN
# 4                       NaN        No              NaN                  NaN
#
#    Combined Energy Efficiency Ratio (CEER)  \
# 0                                     12.1
# 1                                     12.0
# 2                                     12.0
# 3                                     12.0
# 4                                     12.0
#
#    Percent Less Energy Use than US Federal Standard  \
# 0                                                10
# 1                                                10
# 2                                                10
# 3                                                10
# 4                                                10
#
#    Annual Energy Use (kWh/yr) Connected Capable Connects Using  \
# 0                         372                No            NaN
# 1                         500                No            NaN
# 2                         500                No            NaN
# 3                         625                No            NaN
# 4                         750                No            NaN
#
#   Communication Hardware Architecture DR Protocol  \
# 0                                 NaN         NaN
# 1                                 NaN         NaN
# 2                                 NaN         NaN
# 3                                 NaN         NaN
# 4                                 NaN         NaN
#
#    Primary Communication Module/Device Brand Name and Model Number  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Network Security Standards  Network Standby Power (watts)  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#    Is Broadband Internet Connection Needed for Demand Response?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Direct on-premises Open-standard Based Interconnection  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Date Available On Market Date Certified                Markets  \
# 0               06/01/2020     06/02/2020  United States, Canada
# 1               06/01/2020     06/02/2020  United States, Canada
# 2               04/12/2017     04/12/2017          United States
# 3               04/12/2017     04/12/2017          United States
# 4               04/12/2017     04/12/2017          United States
#
#                            CB Model Identifier  \
# 0  ES_1126481_BWAM6W**_06022020111638_80044376
# 1  ES_1126481_BWAM8W**_06022020111638_80044376
# 2   ES_1126481_BWAC08WT_04132017080959_0999674
# 3   ES_1126481_BWAC10WT_04132017081011_1011161
# 4   ES_1126481_BWAC12WT_04132017081021_1021858
#
#   Meets ENERGY STAR Most Efficient 2023 Criteria
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No

# %%
room_ac_doe.head()
# Out:
#   Brand_Name_s__s                   Product_Group_Code_Description_s  \
# 0           Midea  (11) With reverse cycle, with louvered sides, ...
# 1      Genie Aire  (8b) Without reverse cycle, without louvered s...
# 2      Genie Aire  (8a) Without reverse cycle, without louvered s...
# 3      Genie Aire  (8b) Without reverse cycle, without louvered s...
# 4              LG  (3) Without reverse cycle, with louvered sides...
#
#     Basic_Model_Number_m Individual_Model_Number_Covered_by_Basic_Model_m  \
# 0  MWCUPWHP-09HEFN8-BCL1                            MWCUPWHP-09HEFN8-BCL1
# 1       GA23-12ERN1-MCI5                                 GA23-12ERN1-MCI5
# 2        GA23-08CRN1-115                                  GA23-08CRN1-115
# 3        GA23-12CRN2-230                                  GA23-12CRN2-230
# 4               LW8024RD                                         LW8024RD
#
#    Cooling_Capacity__BTU_Hour__d  Electrical_Power_Input__Watts__d  \
# 0                         9000.0                             760.0
# 1                        12000.0                            1180.0
# 2                         8300.0                             760.0
# 3                        12000.0                            1120.0
# 4                         8000.0                             710.0
#
#    Combined_Energy_Efficiency_Ratio_d  \
# 0                                16.0
# 1                                 9.5
# 2                                10.6
# 3                                10.5
# 4                                11.4
#
#   Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#              Link_to_FTC_EnergyGuide_Label_s
# 0                      By annual report date
# 1                      By annual report date
# 2                      By annual report date
# 3                      By annual report date
# 4  http://www.lg.com/global/support/ftclabel

# %%
# regexify model number
room_ac_epa['model_number_modified'] = room_ac_epa['Model Number'].apply(regexify_model_number)
room_ac_doe['individual_model_number_modified'] = room_ac_doe['Individual_Model_Number_Covered_by_Basic_Model_m'].apply(regexify_model_number)

# %%
# find epa model number in doe database
def find_epa_model_number_in_doe_database(model_number):
    return room_ac_doe['individual_model_number_modified'].str.contains(model_number, regex=True).any()

room_ac_epa_models_in_doe_database = room_ac_epa[room_ac_epa.model_number_modified.apply(find_epa_model_number_in_doe_database)]
room_ac_epa_models_in_doe_database.to_csv('epa_room_ac_models_in_doe_database.csv', index=False)

room_ac_epa_models_not_in_doe_database = room_ac_epa[~room_ac_epa.model_number_modified.apply(find_epa_model_number_in_doe_database)]
room_ac_epa_models_not_in_doe_database.to_csv('epa_room_ac_models_not_in_doe_database.csv', index=False)

print(len(room_ac_epa_models_in_doe_database))
print(len(room_ac_epa_models_not_in_doe_database))
# Out:
# 719
# 604

# %%
# Delete part of the string that is in parentheses
def delete_parentheses(model_number):
    return re.sub(r'\(.*\)', '', str(model_number))

room_ac_doe['individual_model_number_modified'] = room_ac_doe['individual_model_number_modified'].apply(delete_parentheses)

# %%
room_ac_doe[room_ac_doe['individual_model_number_modified'].str.contains('\(', regex=True)]

# Edit individuall values in the dataframe and replace them.
room_ac_doe.loc[room_ac_doe['individual_model_number_modified'] == 'TWC-06CRD1/L1U(ES', 'individual_model_number_modified'] = 'TWC-06CRD1/L1U'
room_ac_doe.loc[room_ac_doe['individual_model_number_modified'] == 'TWC-08CRD1/L0U(ES)', 'individual_model_number_modified'] = 'TWC-08CRD1/L0U'

# %%
# Find doe model number in epa database
def find_doe_models_in_energy_star(model_number):
    return room_ac_epa['model_number_modified'].str.contains(model_number, regex=True).any()

# DOE models that appear in EPA ENERGY STAR dataset
room_ac_doe_energy_star = room_ac_doe[room_ac_doe.individual_model_number_modified.apply(find_doe_models_in_energy_star)]
room_ac_doe_energy_star.to_csv('doe_room_ac_models_in_energy_star_database.csv', index=False)

# DOE models that do not appear in EPA ENERGY STAR dataset
room_ac_doe_non_energy_star = room_ac_doe[~room_ac_doe.individual_model_number_modified.apply(find_doe_models_in_energy_star)]
room_ac_doe_non_energy_star.to_csv('doe_room_ac_models_not_in_energy_star_database.csv', index=False)

print(len(room_ac_doe_energy_star))
print(len(room_ac_doe_non_energy_star))
# Out:
# 742
# 1201

# %% [markdown]
# # Clothes Dryer Analysis

# %%
clothes_dryer_epa = pd.read_csv('epa_clothes_dryer.csv')

print(len(clothes_dryer_epa))
# Out:
# 566

# %%
clothes_dryer_doe_1 = pd.read_csv('doe_clothes_dryer_1.csv')
clothes_dryer_doe_2 = pd.read_csv('doe_clothes_dryer_2.csv')

print(len(clothes_dryer_doe_1))
print(len(clothes_dryer_doe_2))
# Out:
# 1047
# 673

# %%
# Examine differences between the two DOE datasets
clothes_dryer_doe_1.head()
# Out:
#   Brand_Name_s__s                   Product_Group_Code_Description_s  \
# 0       Criterion  Vented Electric, Standard (4.4 ft3 or greater ...
# 1   Fulgor Milano  Ventless Electric, Compact (240V) (less than 4...
# 2           Midea  Vented Electric, Standard (4.4 ft3 or greater ...
# 3      GE Profile  Vented Electric, Standard (4.4 ft3 or greater ...
# 4      GE Profile                                         Vented Gas
#
#      Basic_Model_Number_m Individual_Model_Number_Covered_by_Basic_Model_m  \
# 0  MDH210-V022/B01EQHS-US                                       CFDE80N1AW
# 1               FM4CD24W1                                        FM4CD24W1
# 2  MDH210-V022/B01EQHS-US                                    MH04ED80/W-PR
# 3                M74E_1_R                                     PTD60EB*R***
# 4                M74G_4_R                                     PTD60GB*R***
#
#    Capacity__cubic_feet__d  Voltage__volts___For_Electric_Models_Only__d  \
# 0                      8.0                                         240.0
# 1                      4.0                                         240.0
# 2                      8.0                                         240.0
# 3                      7.4                                         240.0
# 4                      7.4                                           NaN
#
#    Hourly_BTU_Rating_of_the_Burner__For_Gas_Models_Only__d  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                            22000.0
#
#   Does_the_Dryer_Have_Automatic_Termination_Controls__s  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#    Combined_Energy_Factor__pounds_per_kilowatt_hour__d  \
# 0                                               3.93
# 1                                               2.68
# 2                                               3.73
# 3                                               3.93
# 4                                               3.48
#
#   Cycle_Settings_for_Energy_Test_Cycle___Program_Cycle_Setting_s  \
# 0                                             Normal
# 1                                             Normal
# 2                                             Normal
# 3                                     Normal Cottons
# 4                                     Normal Cottons
#
#   Cycle_Settings_for_Energy_Test_Cycle___Temperature_Setting_s  \
# 0                                             Medium
# 1                                               High
# 2                                             Medium
# 3                                                Hot
# 4                                                Hot
#
#   Cycle_Settings_for_Energy_Test_Cycle___Dryness_Setting_s  \
# 0                                Normal Dry +Eco Dry
# 1                                            Regular
# 2                                         Normal dry
# 3                                                Dry
# 4                                                Dry
#
#   Cycle_Settings_for_Energy_Test_Cycle___Other_Optional_Cycle_Settings_in_the_As_Shipped_Position__If_Applicable__s  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3            ecoDry is default ON for Normal Cottons
# 4            ecoDry is default ON for Normal Cottons
#
#   Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No

# %%
clothes_dryer_doe_2.head()
# Out:
#   Brand_Name_s__s                   Product_Group_Code_Description_s  \
# 0       Criterion  Vented Electric, Standard (4.4 ft3 or greater ...
# 1   Fulgor Milano  Ventless Electric, Compact (240V) (less than 4...
# 2           Midea  Vented Electric, Standard (4.4 ft3 or greater ...
# 3      GE Profile  Vented Electric, Standard (4.4 ft3 or greater ...
# 4      GE Profile                                         Vented Gas
#
#      Basic_Model_Number_m Individual_Model_Number_Covered_by_Basic_Model_m  \
# 0  MDH210-V022/B01EQHS-US                                       CFDE80N1AW
# 1               FM4CD24W1                                        FM4CD24W1
# 2  MDH210-V022/B01EQHS-US                                    MH04ED80/W-PR
# 3                M74E_1_R                                     PTD60EB*R***
# 4                M74G_4_R                                     PTD60GB*R***
#
#    Capacity__cubic_feet__d  Voltage__volts___For_Electric_Models_Only__d  \
# 0                      8.0                                         240.0
# 1                      4.0                                         240.0
# 2                      8.0                                         240.0
# 3                      7.4                                         240.0
# 4                      7.4                                           NaN
#
#    Hourly_BTU_Rating_of_the_Burner__For_Gas_Models_Only__d  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                            22000.0
#
#   Does_the_Dryer_Have_Automatic_Termination_Controls__s  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#    Combined_Energy_Factor__pounds_per_kilowatt_hour__d  \
# 0                                               3.93
# 1                                               2.68
# 2                                               3.73
# 3                                               3.93
# 4                                               3.48
#
#   Cycle_Settings_for_Energy_Test_Cycle___Program_Cycle_Setting_s  \
# 0                                             Normal
# 1                                             Normal
# 2                                             Normal
# 3                                     Normal Cottons
# 4                                     Normal Cottons
#
#   Cycle_Settings_for_Energy_Test_Cycle___Temperature_Setting_s  \
# 0                                             Medium
# 1                                               High
# 2                                             Medium
# 3                                                Hot
# 4                                                Hot
#
#   Cycle_Settings_for_Energy_Test_Cycle___Dryness_Setting_s  \
# 0                                Normal Dry +Eco Dry
# 1                                            Regular
# 2                                         Normal dry
# 3                                                Dry
# 4                                                Dry
#
#   Cycle_Settings_for_Energy_Test_Cycle___Other_Optional_Cycle_Settings_in_the_As_Shipped_Position__If_Applicable__s  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3            ecoDry is default ON for Normal Cottons
# 4            ecoDry is default ON for Normal Cottons
#
#   Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No

# %%
# Check if doe_1 database contains all the models in doe_2 database
def find_doe_2_models_in_doe_1_database(model_number):
    return clothes_dryer_doe_1['Individual_Model_Number_Covered_by_Basic_Model_m'].str.contains(model_number, regex=True).any()

clothes_dryer_doe_2[clothes_dryer_doe_2.Individual_Model_Number_Covered_by_Basic_Model_m.apply(find_doe_2_models_in_doe_1_database)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/minjukim/Documents/codes/energystar/data_analysis.ipynb Cell 65 in 5
#       <a href='vscode-notebook-cell:/Users/minjukim/Documents/codes/energystar/data_analysis.ipynb#Y130sZmlsZQ%3D%3D?line=1'>2</a> def find_doe_models_in_doe_database(model_number):
#       <a href='vscode-notebook-cell:/Users/minjukim/Documents/codes/energystar/data_analysis.ipynb#Y130sZmlsZQ%3D%3D?line=2'>3</a>     return clothes_dryer_doe_1['individual_model_number_modified'].str.contains(model_number, regex=True).any()
# ----> <a href='vscode-notebook-cell:/Users/minjukim/Documents/codes/energystar/data_analysis.ipynb#Y130sZmlsZQ%3D%3D?line=4'>5</a> clothes_dryer_doe_2_models_in_doe_1_database = clothes_dryer_doe_2[clothes_dryer_doe_2.individual_model_number_modified.apply(find_doe_models_in_doe_database)]
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'individual_model_number_modified'
