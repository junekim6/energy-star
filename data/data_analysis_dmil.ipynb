# %% [markdown]
# ### Notebook Setup

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('ggplot2')
# require('readr')
# require('extrafont')
# require('dplyr')
# require('reshape2')
# # require('theme538')
# Out:
# R[write to console]: Loading required package: ggplot2
# R[write to console]: Loading required package: readr
#
# R[write to console]: Loading required package: extrafont
#
# R[write to console]: Registering fonts with R
#
# R[write to console]: Loading required package: dplyr
#
# R[write to console]:
# Attaching package: ‘dplyr’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# R[write to console]: Loading required package: reshape2

# %%
# set maximum number of columns to display
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Refrigerator Exploration

# %%
epa_ref = pd.read_csv('epa_residential_refrigerators.csv', dtype={'ENERGY STAR Unique ID': str}).drop_duplicates()
epa_freeze =  pd.read_csv('epa_residential_freezers.csv', dtype={'ENERGY STAR Unique ID': str}).drop_duplicates()
doe_ref = pd.read_csv('doe-refrigerator.csv').drop_duplicates()

# %%
doe_ref
# Out:
#           Brand_Name_s__s                   Product_Group_Code_Description_s  \
# 0             Arctic King  (13A.) Compact all-refrigerators - automatic d...
# 1                   Midea                       (18.) Compact chest freezers
# 2                   Midea  (11A.) Compact all-refrigerators - manual defrost
# 3                 Hisense  (13A.) Compact all-refrigerators - automatic d...
# 4                 Hisense  (13A.) Compact all-refrigerators - automatic d...
# ...                   ...                                                ...
# 9321       Black & Decker  (11A.) Compact all-refrigerators - manual defrost
# 9322       Black & Decker  (11A.) Compact all-refrigerators - manual defrost
# 9323  Professional Series  (11A.) Compact all-refrigerators - manual defrost
# 9324               Golden  (3.) Refrigerator-freezers - automatic defrost...
# 9325               AVANTI  (3.) Refrigerator-freezers - automatic defrost...
#
#      Basic_Model_Number_m Individual_Model_Number_Covered_by_Basic_Model_m  \
# 0            HS-60LN(SNZ)                                       ARM17A5ABB
# 1          HS-259CN(SNZK)                                       MRC07M7AWW
# 2         HS-121LN(S4NZ1)                                       MRM33S9ASL
# 3      BC-94DJ1NA1/HC1(Q)                                        RC33A1GWE
# 4           BC-122/HC1(H)                                      LMS044M6RBE
# ...                   ...                                              ...
# 9321               KS-48R                                          BCRK17B
# 9322               KS-48R                                          BCRK17W
# 9323               KS-91R                                     PS-RF739-I6A
# 9324               BCD290                                           BCD290
# 9325            FF1011D1B                                        FF1011D1B
#
#       Total_Adjusted_Volume__Cubic_Feet__d  \
# 0                                      1.7
# 1                                     12.3
# 2                                      3.3
# 3                                      3.3
# 4                                      4.4
# ...                                    ...
# 9321                                   1.7
# 9322                                   1.7
# 9323                                   3.2
# 9324                                  12.1
# 9325                                  12.1
#
#       Annual_Energy_Use__Kilowatt_Hours_Year__d  \
# 0                                         246.0
# 1                                         225.0
# 2                                         220.0
# 3                                         260.0
# 4                                         269.0
# ...                                         ...
# 9321                                      232.0
# 9322                                      232.0
# 9323                                      219.0
# 9324                                      331.0
# 9325                                      331.0
#
#       Total_Refrigerated_Volume__ft3__d  \
# 0                                   1.7
# 1                                   7.0
# 2                                   3.3
# 3                                   3.3
# 4                                   4.4
# ...                                 ...
# 9321                                1.7
# 9322                                1.7
# 9323                                3.2
# 9324                               10.1
# 9325                               10.1
#
#      Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s  \
# 0                                                    No
# 1                                                    No
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 9321                                                 No
# 9322                                                 No
# 9323                                                 No
# 9324                                                 No
# 9325                                                 No
#
#      Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s  \
# 0                                                    No
# 1                                                    No
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 9321                                                 No
# 9322                                                 No
# 9323                                                 No
# 9324                                                 No
# 9325                                                 No
#
#                         Link_to_FTC_EnergyGuide_Label_s
# 0     https://wx1.sinaimg.cn/mw2000/7db66851ly1h1861...
# 1                                 By annual report date
# 2                                 By annual report date
# 3     https://www.hisense-canada.com/en/home-applian...
# 4     https://www.hisense-canada.com/en/home-applian...
# ...                                                 ...
# 9321                              By annual report date
# 9322                              By annual report date
# 9323                              By annual report date
# 9324                              By annual report date
# 9325                              By annual report date
#
# [9162 rows x 10 columns]

# %%
print(f"There are {epa_ref.shape} items in epa_ref. Here are the columns:")
display(epa_ref.head(1))
print(f"There are {epa_freeze.shape} items in epa_freeze. Here are the columns:")
display(epa_freeze.head(1))
print(f"There are {doe_ref.shape} items in doe_ref. Here are the columns:") # way more as expected (because DoE should theoretically be a superset of EPA)
display(doe_ref.head(1))
# Out:
# There are (3444, 32) items in epa_ref. Here are the columns:
#   ENERGY STAR Unique ID   Brand Name Model Number  \
# 0               2369304  Arctic Wind    2ATMW212E
#
#   Additional Model Information  UPC         Type  \
# 0                          NaN  NaN  Top Freezer
#
#                                        Product Class Defrost Type Compact  \
# 0  3 - Refrigerator-freezers - automatic defrost ...    Automatic      No
#
#   Built-in Thru the Door Dispenser Ice Maker Counter Depth  Height (in)  \
# 0       No                      No        No            No         67.0
#
#    Width (in)  Capacity (Total Volume) (ft3)  Adjusted Volume (ft3)  \
# 0        33.0                           21.0                   25.6
#
#    Annual Energy Use (kWh/yr)  US Federal Standard (kWh/yr)  \
# 0                         396                         440.0
#
#    Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 0                                              10.0              NaN
#
#   Refrigerant with GWP Connected Functionality Connects Using  \
# 0                  NaN                      No            NaN
#
#   Connected Functionality Tested Communication Standard Application Layer  \
# 0                            NaN                                      NaN
#
#   Direct on-premises Open-standard Based Interconnection  \
# 0                                                NaN
#
#   Date Available On Market Date Certified                Markets  \
# 0               10/30/2020     11/09/2020  United States, Canada
#
#                            CB Model Identifier  \
# 0  ES_1121980_2ATMW212E_11102020012636_1596636
#
#   Meets ENERGY STAR Most Efficient 2023 Criteria
# 0                                            Yes
# There are (402, 25) items in epa_freeze. Here are the columns:
#   ENERGY STAR Unique ID      Brand Name Model Number  \
# 0               2307583  Danby Premiere   DUFM085A3*
#
#   Additional Model Information          UPC             Type  \
# 0                ,DUFM085A3WP,  67638013994  Upright Freezer
#
#                               Product Class Defrost Type Compact Built-in  \
# 0  8 - Upright freezers with manual defrost       Manual      No       No
#
#   Thru the Door Dispenser Ice Maker  Capacity (Total Volume) (ft3)  \
# 0                      No        No                            8.5
#
#    Adjusted Volume (ft3)  Annual Energy Use (kWh/yr)  \
# 0                   15.0                         247
#
#    US Federal Standard (kWh/yr)  \
# 0                           277
#
#    Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 0                                                11              NaN
#
#   Refrigerant with GWP Connected Functionality Date Available On Market  \
# 0                  NaN                      No               12/12/2017
#
#   Date Certified                Markets  \
# 0     11/30/2017  United States, Canada
#
#                              CB Model Identifier  \
# 0  ES_0031682_DUFM085A3*_12012017104803_70163948
#
#   Meets ENERGY STAR Most Efficient 2023 Criteria
# 0                                             No
# There are (9162, 10) items in doe_ref. Here are the columns:
#   Brand_Name_s__s                   Product_Group_Code_Description_s  \
# 0     Arctic King  (13A.) Compact all-refrigerators - automatic d...
#
#   Basic_Model_Number_m Individual_Model_Number_Covered_by_Basic_Model_m  \
# 0         HS-60LN(SNZ)                                       ARM17A5ABB
#
#    Total_Adjusted_Volume__Cubic_Feet__d  \
# 0                                   1.7
#
#    Annual_Energy_Use__Kilowatt_Hours_Year__d  \
# 0                                      246.0
#
#    Total_Refrigerated_Volume__ft3__d  \
# 0                                1.7
#
#   Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s  \
# 0                                                 No
#
#   Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s  \
# 0                                                 No
#
#                      Link_to_FTC_EnergyGuide_Label_s
# 0  https://wx1.sinaimg.cn/mw2000/7db66851ly1h1861...

# %%
doe_ref[
    # (doe_ref.Brand_Name_s__s == 'Crosley')
    (doe_ref.Basic_Model_Number_m == 'FLOW45')
    & (doe_ref.Individual_Model_Number_Covered_by_Basic_Model_m == 'CRT45')
    # & (doe_ref.Link_to_FTC_EnergyGuide_Label_s == 'By annual report date')
]
# Out:
#      Brand_Name_s__s                   Product_Group_Code_Description_s  \
# 3360         BOUGERV  (11A.) Compact all-refrigerators - manual defrost
# 8075        JOYTUTUS  (11A.) Compact all-refrigerators - manual defrost
# 8078        F40C4TMP  (11A.) Compact all-refrigerators - manual defrost
#
#      Basic_Model_Number_m Individual_Model_Number_Covered_by_Basic_Model_m  \
# 3360               FLOW45                                            CRT45
# 8075               FLOW45                                            CRT45
# 8078               FLOW45                                            CRT45
#
#       Total_Adjusted_Volume__Cubic_Feet__d  \
# 3360                                   1.6
# 8075                                   1.6
# 8078                                   1.6
#
#       Annual_Energy_Use__Kilowatt_Hours_Year__d  \
# 3360                                      180.0
# 8075                                      180.0
# 8078                                      180.0
#
#       Total_Refrigerated_Volume__ft3__d  \
# 3360                                1.6
# 8075                                1.6
# 8078                                1.6
#
#      Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s  \
# 3360                                                 No
# 8075                                                 No
# 8078                                                 No
#
#      Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s  \
# 3360                                                 No
# 8075                                                 No
# 8078                                                 No
#
#      Link_to_FTC_EnergyGuide_Label_s
# 3360           By annual report date
# 8075           By annual report date
# 8078           By annual report date

# %%
(
    # doe_ref.Brand_Name_s__s
    " " +doe_ref.Basic_Model_Number_m
    + " " + doe_ref.Individual_Model_Number_Covered_by_Basic_Model_m
    # + " " + doe_ref.Link_to_FTC_EnergyGuide_Label_s
    # + " " + doe_ref.Annual_Energy_Use__Kilowatt_Hours_Year__d.astype(str)
    # + " " + doe_ref.Total_Refrigerated_Volume__ft3__d.astype(str)
).value_counts()
# Out:
#  FLOW45 CRT45               3
#  CR50 CRT35                 3
#  WL50 CRP48                 3
#  WL50 CRP50                 3
#  FC50D6EWD DSC-185H*        3
#                            ..
#  4w5ig01-06 MFF2055DR*0*    1
#  4w5ig01-06 KRFF300E****    1
#  4w5ibic41 JF42NXFXDE**     1
#  4w5ig00-08 WRFA60SFH*0*    1
#  FF1011D1B FF1011D1B        1
# Length: 9048, dtype: int64

# %%
# columns in epa_ref that aren't in epa_freeze
print(f"Columns in epa_ref that aren't in epa_freeze:")
set(epa_ref.columns) - set(epa_freeze.columns)
# Out:
# Columns in epa_ref that aren't in epa_freeze:
# {'Communication Standard Application Layer',
#  'Connected Functionality Tested',
#  'Connects Using',
#  'Counter Depth',
#  'Direct on-premises Open-standard Based Interconnection',
#  'Height (in)',
#  'Width (in)'}

# %% [markdown]
# ### Exploring the product codes

# %%
# !pip install natsort

# %%
from natsort import natsort_keygen, natsorted
# natural sort (to sort values like 1A, 3B etc...)
# https://stackoverflow.com/questions/29580978/naturally-sorting-pandas-dataframe

# %%
# How many items for each EPA code? 

epa_all = pd.concat([epa_ref, epa_freeze])
epa_codes = epa_all.pivot_table(index='Product Class', values='ENERGY STAR Unique ID', aggfunc='count', fill_value=0)
epa_codes = epa_codes.reset_index().rename(columns={'ENERGY STAR Unique ID': 'count'})
epa_codes_split = epa_codes['Product Class'].str.split(' -', n=1, expand=True).rename(columns={0: 'code', 1: 'description'})
epa_codes = pd.concat([epa_codes_split, epa_codes], axis=1)
epa_codes = epa_codes[['code', 'description', 'count']]
epa_codes.set_index('code', inplace=True)
epa_codes['percent'] = epa_codes['count'] / epa_codes['count'].sum() * 100
with pd.option_context('display.max_colwidth', None, 'display.max_rows', None):
    # display table with title
    display(epa_codes.sort_values('code', key=natsort_keygen()).style.set_caption("EPA Product Class Codes"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_8bc0f">
#   <caption>EPA Product Class Codes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bc0f_level0_col0" class="col_heading level0 col0" >description</th>
#       <th id="T_8bc0f_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_8bc0f_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >code</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bc0f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8bc0f_row0_col0" class="data row0 col0" > Built-in Compact Cooler</td>
#       <td id="T_8bc0f_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_8bc0f_row0_col2" class="data row0 col2" >0.156006</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8bc0f_row1_col0" class="data row1 col0" > Refrigerator-Freezer and Refrigerator other than All-Refrigerator - manual defrost</td>
#       <td id="T_8bc0f_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_8bc0f_row1_col2" class="data row1 col2" >0.078003</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row2" class="row_heading level0 row2" >1A</th>
#       <td id="T_8bc0f_row2_col0" class="data row2 col0" > All-Refrigerators - manual defrost</td>
#       <td id="T_8bc0f_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_8bc0f_row2_col2" class="data row2 col2" >0.104004</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_8bc0f_row3_col0" class="data row3 col0" > Refrigerator-Freezer - partial automatic defrost</td>
#       <td id="T_8bc0f_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_8bc0f_row3_col2" class="data row3 col2" >0.026001</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_8bc0f_row4_col0" class="data row4 col0" > Built-in Cooler</td>
#       <td id="T_8bc0f_row4_col1" class="data row4 col1" >10</td>
#       <td id="T_8bc0f_row4_col2" class="data row4 col2" >0.260010</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_8bc0f_row5_col0" class="data row5 col0" > Refrigerator-freezers - automatic defrost with top-mounted freezer without an automatic ice maker</td>
#       <td id="T_8bc0f_row5_col1" class="data row5 col1" >432</td>
#       <td id="T_8bc0f_row5_col2" class="data row5 col2" >11.232449</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_8bc0f_row6_col0" class="data row6 col0" > Freestanding Compact Cooler</td>
#       <td id="T_8bc0f_row6_col1" class="data row6 col1" >43</td>
#       <td id="T_8bc0f_row6_col2" class="data row6 col2" >1.118045</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row7" class="row_heading level0 row7" >3A</th>
#       <td id="T_8bc0f_row7_col0" class="data row7 col0" > All-Refrigerators - automatic defrost</td>
#       <td id="T_8bc0f_row7_col1" class="data row7 col1" >39</td>
#       <td id="T_8bc0f_row7_col2" class="data row7 col2" >1.014041</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row8" class="row_heading level0 row8" >3A-BI</th>
#       <td id="T_8bc0f_row8_col0" class="data row8 col0" > Built-In All-Refrigerators - automatic defrost</td>
#       <td id="T_8bc0f_row8_col1" class="data row8 col1" >103</td>
#       <td id="T_8bc0f_row8_col2" class="data row8 col2" >2.678107</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row9" class="row_heading level0 row9" >3I</th>
#       <td id="T_8bc0f_row9_col0" class="data row9 col0" > Refrigerator-freezer - automatic defrost with op-mounted freezer with automatic icemaker without through-the-door ice</td>
#       <td id="T_8bc0f_row9_col1" class="data row9 col1" >88</td>
#       <td id="T_8bc0f_row9_col2" class="data row9 col2" >2.288092</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row10" class="row_heading level0 row10" >4</th>
#       <td id="T_8bc0f_row10_col0" class="data row10 col0" > Freestanding Cooler</td>
#       <td id="T_8bc0f_row10_col1" class="data row10 col1" >8</td>
#       <td id="T_8bc0f_row10_col2" class="data row10 col2" >0.208008</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row11" class="row_heading level0 row11" >4I</th>
#       <td id="T_8bc0f_row11_col0" class="data row11 col0" > Refrigerator-freezers - automatic defrost with side-mounted freezer with an automatic icemaker without through-the-door ice service</td>
#       <td id="T_8bc0f_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_8bc0f_row11_col2" class="data row11 col2" >0.078003</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row12" class="row_heading level0 row12" >4I-BI</th>
#       <td id="T_8bc0f_row12_col0" class="data row12 col0" > Built-In Refrigerator-freezers - automatic defrost with side-mounted freezer with an automatic icemaker without through-the-door ice service</td>
#       <td id="T_8bc0f_row12_col1" class="data row12 col1" >4</td>
#       <td id="T_8bc0f_row12_col2" class="data row12 col2" >0.104004</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row13" class="row_heading level0 row13" >5</th>
#       <td id="T_8bc0f_row13_col0" class="data row13 col0" > Refrigerator-freezers - automatic defrost with bottom-mounted freezer without an automatic ice maker</td>
#       <td id="T_8bc0f_row13_col1" class="data row13 col1" >292</td>
#       <td id="T_8bc0f_row13_col2" class="data row13 col2" >7.592304</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row14" class="row_heading level0 row14" >5-BI</th>
#       <td id="T_8bc0f_row14_col0" class="data row14 col0" > Built-In Refrigerator-freezers - automatic defrost with bottom-mounted freezer without an automatic icemaker</td>
#       <td id="T_8bc0f_row14_col1" class="data row14 col1" >38</td>
#       <td id="T_8bc0f_row14_col2" class="data row14 col2" >0.988040</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row15" class="row_heading level0 row15" >5A</th>
#       <td id="T_8bc0f_row15_col0" class="data row15 col0" > Refrigerator-freezers - automatic defrost with bottom-mounted freezer with through-the-door ice service</td>
#       <td id="T_8bc0f_row15_col1" class="data row15 col1" >257</td>
#       <td id="T_8bc0f_row15_col2" class="data row15 col2" >6.682267</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row16" class="row_heading level0 row16" >5I</th>
#       <td id="T_8bc0f_row16_col0" class="data row16 col0" > Refrigerator-freezers - automatic defrost with bottom-mounted freezer with an automatic icemaker without through-the-door ice service</td>
#       <td id="T_8bc0f_row16_col1" class="data row16 col1" >400</td>
#       <td id="T_8bc0f_row16_col2" class="data row16 col2" >10.400416</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row17" class="row_heading level0 row17" >5I-BI</th>
#       <td id="T_8bc0f_row17_col0" class="data row17 col0" > Built-In Refrigerator-freezers - automatic defrost with bottom-mounted freezer with an automatic icemaker without through-the-door ice service</td>
#       <td id="T_8bc0f_row17_col1" class="data row17 col1" >141</td>
#       <td id="T_8bc0f_row17_col2" class="data row17 col2" >3.666147</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row18" class="row_heading level0 row18" >7</th>
#       <td id="T_8bc0f_row18_col0" class="data row18 col0" > Refrigerator-freezers - automatic defrost with side-mounted freezer with through-the-door ice service</td>
#       <td id="T_8bc0f_row18_col1" class="data row18 col1" >63</td>
#       <td id="T_8bc0f_row18_col2" class="data row18 col2" >1.638066</td>
#     </tr>
#     <tr>
#       <th id="T_8bc0f_level0_row19" class="row_heading level0 row19" >7-BI</th>
#       <td id="T_8bc0f_row19_col0" class="data row19 col0" >Built-in refrigerator-freezers - automa

# %%
# code_compare = epa_codes.merge(doe_codes, left_on='code', right_on='code', how='outer', suffixes=(' EPA', ' DoE'))

# %%
# code_compare["description equal"] = code_compare["description EPA"].str.lower().str.strip() == code_compare["description DoE"].str.lower().str.strip()

# %%
# code_compare[["description EPA", "description DoE", "description equal"]]

# %%
# Extract codes from doe into their own column
doe_ref['code'] =  doe_ref['Product_Group_Code_Description_s'].str.extract(r'\((.*)\.\)')

# get unique codes and view them
doe_codes = doe_ref.pivot_table(index='Product_Group_Code_Description_s', values ='Brand_Name_s__s', aggfunc='count', fill_value=0).reset_index()
doe_codes.columns = ['Product_Group_Code_Description_s', 'count']

doe_codes['code'] = doe_codes['Product_Group_Code_Description_s'].str.extract(r'\((.*)\.\)')
doe_codes['description'] = doe_codes['Product_Group_Code_Description_s'].str.extract(r'\(.*\) (.*)')
doe_codes.drop(columns=['Product_Group_Code_Description_s'], inplace=True)
doe_codes = doe_codes[['code', 'description', 'count']]
doe_codes['percent'] = doe_codes['count'] / doe_codes['count'].sum() * 100
doe_codes.set_index('code', inplace=True)

with pd.option_context('display.max_colwidth', None, 'display.max_rows', None):
    # display table with title
    display(doe_codes.sort_values('code', key=natsort_keygen()).style.set_caption("DOE Product Class Codes"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_55128">
#   <caption>DOE Product Class Codes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55128_level0_col0" class="col_heading level0 col0" >description</th>
#       <th id="T_55128_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_55128_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >code</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55128_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_55128_row0_col0" class="data row0 col0" >Refrigerator-freezers and refrigerators other than all-refrigerators with manual defrost</td>
#       <td id="T_55128_row0_col1" class="data row0 col1" >84</td>
#       <td id="T_55128_row0_col2" class="data row0 col2" >0.916830</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row1" class="row_heading level0 row1" >1A</th>
#       <td id="T_55128_row1_col0" class="data row1 col0" >All-refrigerators - manual defrost</td>
#       <td id="T_55128_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_55128_row1_col2" class="data row1 col2" >0.141890</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55128_row2_col0" class="data row2 col0" >Refrigerator-freezers - partial automatic defrost</td>
#       <td id="T_55128_row2_col1" class="data row2 col1" >33</td>
#       <td id="T_55128_row2_col2" class="data row2 col2" >0.360183</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55128_row3_col0" class="data row3 col0" >Refrigerator-freezers - automatic defrost with top-mounted freezer without an automatic icemaker</td>
#       <td id="T_55128_row3_col1" class="data row3 col1" >1169</td>
#       <td id="T_55128_row3_col2" class="data row3 col2" >12.759223</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row4" class="row_heading level0 row4" >3-BI</th>
#       <td id="T_55128_row4_col0" class="data row4 col0" >Built-in refrigerator-freezer - automatic defrost with top-mounted freezer without an automatic icemaker</td>
#       <td id="T_55128_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_55128_row4_col2" class="data row4 col2" >0.032744</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row5" class="row_heading level0 row5" >3A</th>
#       <td id="T_55128_row5_col0" class="data row5 col0" >All-refrigerators - automatic defrost</td>
#       <td id="T_55128_row5_col1" class="data row5 col1" >67</td>
#       <td id="T_55128_row5_col2" class="data row5 col2" >0.731281</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row6" class="row_heading level0 row6" >3A-BI</th>
#       <td id="T_55128_row6_col0" class="data row6 col0" >Built-in All-refrigerators - automatic defrost</td>
#       <td id="T_55128_row6_col1" class="data row6 col1" >148</td>
#       <td id="T_55128_row6_col2" class="data row6 col2" >1.615368</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row7" class="row_heading level0 row7" >3I</th>
#       <td id="T_55128_row7_col0" class="data row7 col0" >Refrigerator-freezers - automatic defrost with top-mounted freezer with an automatic icemaker without through-the-door ice service</td>
#       <td id="T_55128_row7_col1" class="data row7 col1" >917</td>
#       <td id="T_55128_row7_col2" class="data row7 col2" >10.008732</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row8" class="row_heading level0 row8" >3I-BI</th>
#       <td id="T_55128_row8_col0" class="data row8 col0" >Built-in refrigerator-freezers - automatic defrost with top-mounted freezer with an automatic icemaker without through-the-door ice service</td>
#       <td id="T_55128_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_55128_row8_col2" class="data row8 col2" >0.043659</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row9" class="row_heading level0 row9" >4</th>
#       <td id="T_55128_row9_col0" class="data row9 col0" >Refrigerator-freezers - automatic defrost with side-mounted freezer without an automatic icemaker</td>
#       <td id="T_55128_row9_col1" class="data row9 col1" >60</td>
#       <td id="T_55128_row9_col2" class="data row9 col2" >0.654879</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row10" class="row_heading level0 row10" >4I</th>
#       <td id="T_55128_row10_col0" class="data row10 col0" >Refrigerator-freezers - automatic defrost with side-mounted freezer with an automatic icemaker without through-the-door ice service</td>
#       <td id="T_55128_row10_col1" class="data row10 col1" >43</td>
#       <td id="T_55128_row10_col2" class="data row10 col2" >0.469330</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row11" class="row_heading level0 row11" >4I-BI</th>
#       <td id="T_55128_row11_col0" class="data row11 col0" >Built-In Refrigerator-freezers - automatic defrost with side-mounted freezer with an automatic icemaker without through-the-door ice service</td>
#       <td id="T_55128_row11_col1" class="data row11 col1" >62</td>
#       <td id="T_55128_row11_col2" class="data row11 col2" >0.676708</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row12" class="row_heading level0 row12" >5</th>
#       <td id="T_55128_row12_col0" class="data row12 col0" >Refrigerator-freezers - automatic defrost with bottom-mounted freezer without an automatic icemaker</td>
#       <td id="T_55128_row12_col1" class="data row12 col1" >470</td>
#       <td id="T_55128_row12_col2" class="data row12 col2" >5.129884</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row13" class="row_heading level0 row13" >5-BI</th>
#       <td id="T_55128_row13_col0" class="data row13 col0" >Built-In Refrigerator-freezers - automatic defrost with bottom-mounted freezer without an automatic icemaker</td>
#       <td id="T_55128_row13_col1" class="data row13 col1" >37</td>
#       <td id="T_55128_row13_col2" class="data row13 col2" >0.403842</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row14" class="row_heading level0 row14" >5A</th>
#       <td id="T_55128_row14_col0" class="data row14 col0" >Refrigerator-freezer - automatic defrost with bottom-mounted freezer with through-the-door ice service</td>
#       <td id="T_55128_row14_col1" class="data row14 col1" >582</td>
#       <td id="T_55128_row14_col2" class="data row14 col2" >6.352325</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row15" class="row_heading level0 row15" >5I</th>
#       <td id="T_55128_row15_col0" class="data row15 col0" >Refrigerator-freezers - automatic defrost with bottom-mounted freezer with an automatic icemaker without through-the-door ice service</td>
#       <td id="T_55128_row15_col1" class="data row15 col1" >1239</td>
#       <td id="T_55128_row15_col2" class="data row15 col2" >13.523248</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row16" class="row_heading level0 row16" >5I-BI</th>
#       <td id="T_55128_row16_col0" class="data row16 col0" >Built-In Refrigerator-freezers - automatic defrost with bottom-mounted freezer with an automatic icemaker without through-the-door ice service</td>
#       <td id="T_55128_row16_col1" class="data row16 col1" >313</td>
#       <td id="T_55128_row16_col2" class="data row16 col2" >3.416285</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row17" class="row_heading level0 row17" >7</th>
#       <td id="T_55128_row17_col0" class="data row17 col0" >Refrigerator-freezers - automatic defrost with side-mounted freezer with through-the-door ice service</td>
#       <td id="T_55128_row17_col1" class="data row17 col1" >567</td>
#       <td id="T_55128_row17_col2" class="data row17 col2" >6.188605</td>
#     </tr>
#     <tr>
#       <th id="T_55128_level0_row18" class="row_heading level0 row18" >7-BI</th>
#       <td id="T_55128_row18_col0" class="data row18 col0" >Built-In Refrigerator-freezers - automatic defrost with side-mounte

# %% [markdown]
# So the product codes are comparable for the most part, but messy. EPA sometimes has the same product code twice with different descriptions. If we want to compare across codes, we may have to do some cleanup. Additionally, the codes seem like a combo of categories like "compact" or "upright". We may want to turn these into binary variables if that distinction matters. It seems like there are more compact fridges in the EPA dataset. We'll see if that is still the case after we separate out the duplicates, but that's just something to keep in mind before we take a mean. Do we need to treat different subsets of the data differntly? Are compact fridges inherently more efficient than other types of fridges? If so, having more compact fridges might skew the mean.

# %% [markdown]
# ### Overview
#
# Questions:
# - lot more epa refrigerators than freezers (I'll want to check both for duplicates prior to joining)
# - lot more doe than epa (this is expected as doe *should*  be a superset of epa - i'll want to check that this is the case and if not what are the diffs and can we explain them)

# %%
display(epa_ref.describe().round(1))
display(epa_freeze.describe().round(1))
display(doe_ref.describe().round(1))
# Out:
#        Height (in)  Width (in)  Capacity (Total Volume) (ft3)  \
# count       3444.0      3444.0                         3444.0
# mean          53.0        25.9                           12.0
# std           20.2         7.4                            8.5
# min           14.0        14.6                            1.0
# 25%           33.3        19.0                            3.3
# 50%           64.8        24.0                           10.7
# 75%           69.8        31.1                           19.4
# max           84.5        65.6                           31.6
#
#        Adjusted Volume (ft3)  Annual Energy Use (kWh/yr)  \
# count                 3444.0                      3444.0
# mean                    14.2                       376.9
# std                     10.7                       163.5
# min                      1.0                        88.0
# 25%                      3.8                       230.0
# 50%                     12.6                       327.0
# 75%                     23.0                       498.2
# max                     39.9                       807.0
#
#        US Federal Standard (kWh/yr)  \
# count                        3436.0
# mean                          427.6
# std                           172.1
# min                           168.0
# 25%                           287.0
# 50%                           371.0
# 75%                           563.2
# max                           885.0
#
#        Percent Less Energy Use than US Federal Standard
# count                                            3436.0
# mean                                               13.0
# std                                                 6.7
# min                                               -32.0
# 25%                                                10.0
# 50%                                                11.0
# 75%                                                13.0
# max                                                61.0
#        Capacity (Total Volume) (ft3)  Adjusted Volume (ft3)  \
# count                          402.0                  402.0
# mean                            11.1                   19.5
# std                              6.1                   10.6
# min                              1.1                    1.9
# 25%                              5.8                   10.3
# 50%                             11.2                   19.8
# 75%                             15.8                   27.8
# max                             21.7                   38.1
#
#        Annual Energy Use (kWh/yr)  US Federal Standard (kWh/yr)  \
# count                       402.0                         402.0
# mean                        369.3                         422.1
# std                         114.4                         132.1
# min                         137.0                         178.0
# 25%                         241.0                         272.0
# 50%                         394.0                         438.0
# 75%                         452.0                         530.0
# max                         649.0                         717.0
#
#        Percent Less Energy Use than US Federal Standard
# count                                             402.0
# mean                                               12.7
# std                                                 4.6
# min                                                 8.0
# 25%                                                10.0
# 50%                                                11.0
# 75%                                                13.0
# max                                                37.0
#        Total_Adjusted_Volume__Cubic_Feet__d  \
# count                                9162.0
# mean                                   18.6
# std                                    10.3
# min                                     1.5
# 25%                                     8.3
# 50%                                    22.0
# 75%                                    25.9
# max                                    44.0
#
#        Annual_Energy_Use__Kilowatt_Hours_Year__d  \
# count                                     9162.0
# mean                                       443.5
# std                                        165.1
# min                                        110.0
# 25%                                        297.0
# 50%                                        436.0
# 75%                                        575.0
# max                                        885.0
#
#        Total_Refrigerated_Volume__ft3__d
# count                             9162.0
# mean                                14.8
# std                                  7.9
# min                                  1.1
# 25%                                  5.7
# 50%                                 17.7
# 75%                                 20.5
# max                                 31.5

# %% [markdown]
# ## What are the differences between EPA and DOE data?

# %%
# plot histograms of cubic feet 
display(doe_ref['Total_Adjusted_Volume__Cubic_Feet__d'].hist(bins=30, figsize=(16, 4))) # blue
display(epa_ref['Adjusted Volume (ft3)'].hist(bins=30, figsize=(16, 4))) # orange
display(epa_freeze['Adjusted Volume (ft3)'].hist(bins=30, figsize=(16, 4))) # green


# add title
plt.title('Refrigerator Volume (ft3) in each dataset')
# Out:
# <AxesSubplot: >
# <AxesSubplot: >
# <AxesSubplot: >
# Text(0.5, 1.0, 'Refrigerator Volume (ft3) in each dataset')

# %% [markdown]
# It seems to me that there are probably two types of fridges, the small ones and the big ones...the distribution of the freezers seems a bit more uniform.
#
# The two peaks on the DOE data (blue histogram) are about equal height, whereas the right peak is way smaller than the left peak in the EPA data (orange histogram). This could mean that the EPA data has more minifridges, relatively speaking. I'm not totally sure yet, but I'm getting the sense that the types of fridges differ in each dataset (note, at this point these datsets overlap...we will try to separate them in the next step), so taking the mean across all fridges may not be methodologically sound if for instance, by their nature big fridges are just less efficient than small ones and one dataset just contains more of one than another relatively speaking. What about vertical vs horizontal ones (heat rises, does it take more energy to have a freezer on top vs on bottom?). Is it fair to compare fridge/refrigerator combos to just fridges alone. Are toploading (icebox style) fridges comparable to side-loading fridges? Does the EPA take into consideration these distinctions? What (if anything) do we need to control for?
#
# All worth thinking about.

# %% [markdown]
# ## Efficiency
#
# Before I do any joining and merging etc, let me just take a quick look at one more column, since we plan to calculate energy efficiency, let's look at that too across these three datasets.

# %%
epa_ref['energy_per_volume'] = epa_ref['Annual Energy Use (kWh/yr)'] / epa_ref['Adjusted Volume (ft3)']
epa_freeze['energy_per_volume'] = epa_freeze['Annual Energy Use (kWh/yr)'] / epa_freeze['Adjusted Volume (ft3)']
doe_ref['energy_per_volume'] = doe_ref['Annual_Energy_Use__Kilowatt_Hours_Year__d'] / doe_ref['Total_Adjusted_Volume__Cubic_Feet__d']

# %%
# plot energy_per_volume
display(doe_ref['energy_per_volume'].hist(bins=30, figsize=(16, 4))) # blue
display(epa_ref['energy_per_volume'].hist(bins=30, figsize=(16, 4))) # orange
display(epa_freeze['energy_per_volume'].hist(bins=30, figsize=(16, 4))) # green

# add title
plt.title('Energy per Volume (kWh/yr/ft3)')
# Out:
# <AxesSubplot: >
# <AxesSubplot: >
# <AxesSubplot: >
# Text(0.5, 1.0, 'Energy per Volume (kWh/yr/ft3)')

# %% [markdown]
# ## Separate Compact and Standard Refrigerators

# %%
# Seaparate out EPA compact refrigerators and standard refrigerators
epa_all['energy_per_volume'] = epa_all['Annual Energy Use (kWh/yr)'] / epa_all['Adjusted Volume (ft3)']

epa_all_compact = epa_all[epa_all['Compact']=="Yes"]
epa_all_standard = epa_all[epa_all['Compact']=="No"]

# %%
display(epa_all_standard.shape)
display(epa_all_compact.shape)
# Out:
# (2171, 33)
# (1675, 33)

# %%
epa_all_standard
# Out:
#     ENERGY STAR Unique ID   Brand Name Model Number  \
# 0                 2369304  Arctic Wind    2ATMW212E
# 3                 2370277  Arctic Wind     ABM*171E
# 4                 2370276  Arctic Wind    ABM*171E*
# 5                 2329929  Arctic Wind     ATMB212E
# 6                 2329930  Arctic Wind    ATMSL212E
# ..                    ...          ...          ...
# 396               2358327      Whynter   UDF-0831SS
# 397               2235482      Whynter    UDF-138DW
# 398               2328022      Whynter    UDF-139SS
# 399               2386091        WINIA  W*FU021A*E#
# 401               2453178        Zline    RBCFVL-18
#
#                           Additional Model Information  \
# 0                                                  NaN
# 3    ,,The symbol *, maybe replaced by A-Z, means d...
# 4    ,,The symbol *, maybe replaced by A-Z, means d...
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 396                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 401                                        ,RBCFVR-18,
#
#                            UPC             Type  \
# 0                          NaN      Top Freezer
# 3                          NaN   Bottom Freezer
# 4                          NaN   Bottom Freezer
# 5                          NaN      Top Freezer
# 6                          NaN      Top Freezer
# ..                         ...              ...
# 396                        NaN  Upright Freezer
# 397                        NaN  Upright Freezer
# 398               852749006665  Upright Freezer
# 399                        NaN  Upright Freezer
# 401  195948020989;195948021962  Upright Freezer
#
#                                          Product Class Defrost Type Compact  \
# 0    3 - Refrigerator-freezers - automatic defrost ...    Automatic      No
# 3    5 - Refrigerator-freezers - automatic defrost ...    Automatic      No
# 4    5 - Refrigerator-freezers - automatic defrost ...    Automatic      No
# 5    3 - Refrigerator-freezers - automatic defrost ...    Automatic      No
# 6    3 - Refrigerator-freezers - automatic defrost ...    Automatic      No
# ..                                                 ...          ...     ...
# 396  9 - Upright freezers with automatic defrost wi...    Automatic      No
# 397  9 - Upright freezers with automatic defrost wi...    Automatic      No
# 398  9 - Upright freezers with automatic defrost wi...    Automatic      No
# 399  9 - Upright freezers with automatic defrost wi...    Automatic      No
# 401  9I-BI - Built-In upright freezers with automat...    Automatic      No
#
#     Built-in Thru the Door Dispenser Ice Maker Counter Depth  Height (in)  \
# 0         No                      No        No            No         67.0
# 3         No                      No        No            No         69.1
# 4         No                      No        No            No         69.1
# 5         No                      No        No            No         67.0
# 6         No                      No        No            No         67.0
# ..       ...                     ...       ...           ...          ...
# 396       No                      No        No           NaN          NaN
# 397       No                      No        No           NaN          NaN
# 398       No                      No        No           NaN          NaN
# 399       No                      No        No           NaN          NaN
# 401      Yes                     Yes       Yes           NaN          NaN
#
#      Width (in)  Capacity (Total Volume) (ft3)  Adjusted Volume (ft3)  \
# 0          33.0                           21.0                   25.6
# 3          31.3                           17.1                   20.9
# 4          31.3                           17.1                   20.9
# 5          33.0                           21.0                   25.6
# 6          33.0                           21.0                   25.6
# ..          ...                            ...                    ...
# 396         NaN                            8.3                   14.6
# 397         NaN                           13.8                   24.3
# 398         NaN                           13.8                   24.3
# 399         NaN                           20.8                   36.7
# 401         NaN                            8.7                   15.3
#
#      Annual Energy Use (kWh/yr)  US Federal Standard (kWh/yr)  \
# 0                           396                         440.0
# 3                           451                         502.0
# 4                           451                         502.0
# 5                           396                         440.0
# 6                           396                         440.0
# ..                          ...                           ...
# 396                         317                         354.0
# 397                         391                         438.0
# 398                         394                         438.0
# 399                         489                         545.0
# 401                         452                         496.0
#
#      Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 0                                                10.0              NaN
# 3                                                10.0           R-600a
# 4                                                10.0           R-600a
# 5                                                10.0              NaN
# 6                                                10.0              NaN
# ..                                                ...              ...
# 396                                              10.0              NaN
# 397                                              11.0              NaN
# 398                                              10.0              NaN
# 399                                              10.0           R-600a
# 401                                              11.0              NaN
#
#            Refrigerant with GWP Connected Functionality Connects Using  \
# 0                           NaN                      No            NaN
# 3    R-600a (GWP:3 | Lower GWP)                      No            NaN
# 4    R-600a (GWP:3 | Lower GWP)                      No            NaN
# 5                           NaN                      No            NaN
# 6                           NaN                      No            NaN
# ..                          ...                     ...            ...
# 396                         NaN                      No            NaN
# 397                         NaN                      No            NaN
# 398                         NaN                      No            NaN
# 399  R-600a (GWP:3 | Lower GWP)                      No            NaN
# 401                         NaN                      No            NaN
#
#     Connected Functionality Tested Communication Standard Application Layer  \
# 0                              NaN                                      NaN
# 3                              NaN                                      NaN
# 4                              NaN                                      NaN
# 5                              NaN                                      NaN
# 6                              NaN                                      NaN
# ..                             ...                                      ...
# 396                            NaN                                      NaN
# 397                            NaN                                      NaN
# 398                            NaN                                      NaN
# 399                            NaN                                      NaN
# 401                            NaN                                      NaN
#
#     Direct on-premises Open-standard Based Interconnection  \
# 0                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 396                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 401                                                NaN
#
#     Date Available On Market Date Certified                Markets  \
# 0                 10/30/2020     11/09/2020  United States, Canada
# 3                 11/23/2020     11/25/2020  United States, Canada
# 4                 11/23/2020     11/25/2020  United States, Canada
# 5                 11/10/2018     11/14/2018  United States, Canada
# 6                 11/10/2018     11/14/2018  United States, Canada
# ..                       ...            ...                    ...
# 396               04/22/2020     04/20/2020  United States, Canada
# 397               03/27/2015     03/27/2015  United States, Canada
# 398               10/15/2018     02/03/2023  United States, Canada
# 399               03/10/2021     10/14/2021          United States
# 401               03/30/2023     04/11/2023  United States, Canada
#
#                                 CB Model Identifier  \
# 0       ES_1121980_2ATMW212E_11102020012636_1596636
# 3       ES_1121980_ABM*171E_112520200126738_9572853
# 4       ES_1121980_ABM*171E*_11252020012627_7795251
# 5        ES_1121980_ATMB212E_11142018075857_2337900
# 6       ES_1121980_ATMSL212E_11142018075847_2327351
# ..                                              ...
# 396  ES_1122240_UDF-0831SS _04222020093418_80041090
# 397    ES_1122240_UDF-138DW_03312015031110_70027805
# 398     ES_1122240_UDF-139SS_10182018022602_9562210
# 399  ES_1108205_W*FU021A*E#_101220210200432_3338165
# 401     ES_1145610_RBCFVL-18_03292023132335_5841638
#
#     Meets ENERGY STAR Most Efficient 2023 Criteria  energy_per_volume
# 0                                              Yes          15.468750
# 3                                               No          21.578947
# 4                                               No          21.578947
# 5                                              Yes          15.468750
# 6                                              Yes          15.468750
# ..                                             ...                ...
# 396                                             No          21.712329
# 397                                             No          16.090535
# 398                                             No          16.213992
# 399                                             No          13.324251
# 401                                             No          29.542484
#
# [2171 rows x 33 columns]

# %%
# Separate out DOE compact refrigerators and standard refrigerators

doe_ref_compact = doe_ref[doe_ref['Product_Group_Code_Description_s'].str.lower().str.contains('compact')]
doe_ref_standard = doe_ref[~doe_ref['Product_Group_Code_Description_s'].str.lower().str.contains('compact')]

# %%
# Check if the DOE basic model number is the same, whether the energy use is the same.
# If it is, then we can use the DOE data to fill in the missing energy use data in the EPA data.

# First, let's see how many unique basic model numbers there are in the dataset
print(f"There are {len(doe_ref['Basic_Model_Number_m'].unique())} unique basic model numbers in the DOE dataset.")

def check_if_same_basic_model_has_same_energy_use(model):
    same_basic_models = doe_ref[doe_ref['Basic_Model_Number_m'] == model]
    if len(same_basic_models) > 1:
        # print(f"Found {len(same_basic_models)} models with the same basic model number.")
        # print(same_basic_models[['ENERGY_STAR_Model_Indicator_s', 'Annual_Energy_Use__Kilowatt_Hours_Year__d']])
        # print(same_basic_models['Annual_Energy_Use__Kilowatt_Hours_Year__d'].unique())
        if len(same_basic_models['Annual_Energy_Use__Kilowatt_Hours_Year__d'].unique()) == 1:
            return True
        else:
            return False

doe_ref['same_energy_use'] = doe_ref['Basic_Model_Number_m'].apply(check_if_same_basic_model_has_same_energy_use)
# Out:
# There are 4060 unique basic model numbers in the DOE dataset.

# %%
doe_ref[doe_ref['same_energy_use'] == False]['Basic_Model_Number_m'].unique()
# Out:
# array(['BCD-95ANB', 'BCD-586WI', 'BCD-127-E', 'BC-128C-E', 'BCD-523W',
#        'DL1-153', 'UL-BD198-D', 'FC2-37', 'BC-50', 'B35C5BL', 'BC-47-62H',
#        'DF1-11.2', 'BC-128-E', 'K56300NEB', 'K56300NEBLU', 'K60365N',
#        'K76540NEB', 'K74505N', 'K70520N', 'D70420N', 'HS-507FWENDT',
#        'HD-273FN', 'HD-774FWEN', 'HS-121LN(S3NZ)', 'HD-676RWEN',
#        'HD-113FN(S5NZ1)', 'MCB 36', 'CS 20', 'UL-BD400-D', 'BC-70C-E',
#        'GLR10TRDEFR', 'GLR31TBKER', 'RF170A', 'RF170B', 'RF201A',
#        'RF170W', 'RF135B', 'CTR19W', 'D70440NU', 'HZF3362E', 'CTR19B',
#        'CTR19SS', 'CTR22B', 'CTR22W', 'CTR22SS', 'HTS1561X2',
#        'BCD160WD/HC', 'FF1072B', 'FF1427W', 'FF1073SS', 'FFBF279SSB',
#        'FC2-26', 'FF1118W', 'FFBF249SSB', 'FF1159SS', 'FF1119B',
#        'JC-70WS/HC', 'FF948', 'K60365NU', 'K70520NU', 'HS-125SEN',
#        'DL1-112FDR', 'XS8990TS', 'XS7490TS', 'S8990TST', 'S7490TST',
#        'BV024', 'RE124', 'RE115', 'NH*****-**01A', 'GLR10TBKEFR',
#        'W2_11A_M', 'FC34D6EWD', 'FC87D6EWD', 'FC70D6EWE', 'BFTF2716WHIM',
#        'BD-88B-E', 'BCD-740WPZR/HC', 'BD1-145', 'BCD-543WP2BF1Z6/HC1(H)',
#        'BCD-587WID', 'BC-90U-E', 'BCD-90-E', 'BC-46-E', 'HRM145N6AVD',
#        'F70420NE', 'X50', '463(x)', 'HQ-679RWEN(UR-BCD522WX1-SQ)',
#        'HTS1561X', 'BC-121/HC1(H)', 'HQ-679RWEN', 'KS-91R',
#        'HS-87LN(S3NZ)', 'GLR31TRDER', 'BC-128', 'ALPRF66B', 'FF1071W',
#        'FF1161KS', 'FF1427SS', 'BC-140WSD-6', 'FF946', 'HTS1568',
#        'FFBF181ESB', 'D70420NU', 'BD-590WY/HC1(H)'], dtype=object)

# %%
doe_ref.query('Basic_Model_Number_m == "FC2-37"')[[
    'Brand_Name_s__s',
    # 'Product_Group_Code_Description_s',
    'Basic_Model_Number_m',
    'Individual_Model_Number_Covered_by_Basic_Model_m',
    'Annual_Energy_Use__Kilowatt_Hours_Year__d',
    # 'energy_per_volume'
]].sort_values('Individual_Model_Number_Covered_by_Basic_Model_m')
# Out:
#           Brand_Name_s__s Basic_Model_Number_m  \
# 5698               AVANTI               FC2-37
# 1010               AVANTI               FC2-37
# 1316           Frigidaire               FC2-37
# 5671           MAGIC COOL               FC2-37
# 989            MAGIC COOL               FC2-37
# 346       Premium Levella               FC2-37
# 345       Premium Levella               FC2-37
# 4550  Professional Series               FC2-37
#
#      Individual_Model_Number_Covered_by_Basic_Model_m  \
# 5698                                          FF10B0W
# 1010                                          FF10B3S
# 1316                                       FFET1022U*
# 5671                                          MCR10SI
# 989                                           MCR10WI
# 346                                        PRN10150HW
# 345                                        PRN10160HS
# 4550                                         PS-RF262
#
#       Annual_Energy_Use__Kilowatt_Hours_Year__d
# 5698                                      320.0
# 1010                                      320.0
# 1316                                      297.0
# 5671                                      320.0
# 989                                       320.0
# 346                                       297.0
# 345                                       297.0
# 4550                                      330.0

# %%
display(len(epa_all_compact)/len(epa_all))
display(len(doe_ref_compact)/len(doe_ref))
# Out:
# 0.43551742069682786
# 0.30681074001309755

# %%
doe_ref_standard.shape
# Out:
# (6351, 12)

# %%
display(len(epa_all_standard)/len(epa_all))
display(len(doe_ref_standard)/len(doe_ref))
# Out:
# 0.5644825793031721
# 0.6931892599869024

# %% [markdown]
# ## Compare average efficiency of standard refrigerators

# %%
print(f"The average energy per volume for EPA standard refrigerators is {epa_all_standard.energy_per_volume.mean():.2f} kWh/yr/ft3")
display(epa_all_standard.energy_per_volume.describe())

print(f"The average energy per volume for DOE standard refrigerators is {doe_ref_standard.energy_per_volume.mean():.2f} kWh/yr/ft3")
display(doe_ref_standard.energy_per_volume.describe())
# Out:
# The average energy per volume for EPA standard refrigerators is 21.36 kWh/yr/ft3
# count    2171.000000
# mean       21.361876
# std         4.880687
# min         8.324607
# 25%        18.061224
# 50%        21.232227
# 75%        23.864542
# max        80.666667
# Name: energy_per_volume, dtype: float64
# The average energy per volume for DOE standard refrigerators is 22.02 kWh/yr/ft3
# count    6351.000000
# mean       22.016807
# std         3.784522
# min         9.833795
# 25%        19.421965
# 50%        22.131980
# 75%        24.160305
# max        49.468085
# Name: energy_per_volume, dtype: float64

# %% [markdown]
# So it looks like the DOE dataset has a similar distribution, but with WAY more low energy per volume (high efficiency) datapoints. I wonder why. And what is the relationship between this efficiency measure and the size of the fridge? Again, we'll try this later on after de-duping across the datasets.

# %%
# Plot energy per volume for standard refrigerators
display(doe_ref_standard['energy_per_volume'].hist(bins=30, figsize=(16, 8), color='red', alpha=0.4, label='DOE'))
display(epa_all_standard['energy_per_volume'].hist(bins=30, figsize=(16, 8), color='green', alpha=0.4, label='EPA'))

# Add title
plt.title('Energy per Volume (kWh/yr/ft3) for Standard Refrigerators')

# Add legend
plt.legend()

# Add average lines
plt.axvline(doe_ref_standard.energy_per_volume.mean(), color='red', linestyle='dashed', linewidth=1)
plt.axvline(epa_all_standard.energy_per_volume.mean(), color='green', linestyle='dashed', linewidth=1)
# Out:
# <AxesSubplot: >
# <AxesSubplot: >

# %%
more_energy_than_doe_average_standard = epa_all_standard[epa_all_standard.energy_per_volume > doe_ref_standard.energy_per_volume.mean()]['Model Number'].count()/epa_all_standard['Model Number'].count()

print(f"{more_energy_than_doe_average_standard:.2%} of EPA standard refrigerators use more energy per volume than the average DOE standard refrigerator.")
# Out:
# 39.47% of EPA standard refrigerators use more energy per volume than the average DOE standard refrigerator.

# %% [markdown]
# ## Compare average efficiency of compact refrigerators

# %%
print(f"The average energy per volume for EPA compact refrigerators is {epa_all_compact.energy_per_volume.mean():.2f} kWh/yr/ft3")
display(epa_all_compact.energy_per_volume.describe())

print(f"The average energy per volume for DOE compact refrigerators is {doe_ref_compact.energy_per_volume.mean():.2f} kWh/yr/ft3")
display(doe_ref_compact.energy_per_volume.describe())
# Out:
# The average energy per volume for EPA compact refrigerators is 70.78 kWh/yr/ft3
# count    1675.000000
# mean       70.781823
# std        29.310621
# min        16.097561
# 25%        51.363636
# 50%        66.666667
# 75%        82.820513
# max       241.000000
# Name: energy_per_volume, dtype: float64
# The average energy per volume for DOE compact refrigerators is 65.22 kWh/yr/ft3
# count    2811.000000
# mean       65.219413
# std        33.420332
# min         9.081365
# 25%        46.036109
# 50%        60.800000
# 75%        84.210526
# max       181.333333
# Name: energy_per_volume, dtype: float64

# %%
display(doe_ref_compact['energy_per_volume'].hist(bins=30, figsize=(16, 8), color='red', alpha=0.4, label='DOE'))
display(epa_all_compact['energy_per_volume'].hist(bins=30, figsize=(16, 8), color='green', alpha=0.4, label='EPA'))


# Add title
plt.title('Energy per Volume (kWh/yr/ft3) for Compact Refrigerators')

# Add legend
plt.legend()

# Add average lines
plt.axvline(doe_ref_compact.energy_per_volume.mean(), color='red', linestyle='dashed', linewidth=1)
plt.axvline(epa_all_compact.energy_per_volume.mean(), color='green', linestyle='dashed', linewidth=1)
# Out:
# <AxesSubplot: >
# <AxesSubplot: >

# %%
more_energy_than_doe_average_compact = epa_all_compact[epa_all_compact.energy_per_volume > doe_ref_compact.energy_per_volume.mean()]['Model Number'].count()/epa_all_compact['Model Number'].count()

print(f"{more_energy_than_doe_average_compact:.2%} of EPA compact refrigerators use more energy per volume than the average DOE compact refrigerator.")
# Out:
# 51.82% of EPA compact refrigerators use more energy per volume than the average DOE compact refrigerator.

# %% [markdown]
# # Understanding Duplicates

# %% [markdown]
# prior to combining `epa_ref` and `epa_freeze` let's explore them

# %%
# There should have mututally exclusive sets of IDs (THERE ARE)
set(epa_ref['ENERGY STAR Unique ID']).intersection(set(epa_freeze['ENERGY STAR Unique ID'])) == set()
# Out:
# True

# %%
# There should have mututally exclusive sets of Model Number
model_numbers_in_both = set(epa_ref['Model Number']).intersection(set(epa_freeze['Model Number']))
print(f"There are {len(model_numbers_in_both)} model numbers in both epa_ref and epa_freeze. What's up with that?")
model_numbers_in_both
# Out:
# There are 13 model numbers in both epa_ref and epa_freeze. What's up with that?
# {'AU83ETWBR1RCM',
#  'BD-305WE-B-A-62H',
#  'BD-305WE-B-A1-62H',
#  'EUF14CE**',
#  'FGVU21F8QF*',
#  'HVUF11SL',
#  'HVUF11SLF',
#  'KMR11MS2EA16C',
#  'LRU14F3ASTC',
#  'LRU14F3AWWC',
#  'RB36S',
#  'VF108K0W',
#  'VSF11US2A16'}

# %% [markdown]
# you can explore those in the cell below

# %%
model_number_to_view = 'AU83ETWBR1RCM'
display(epa_ref.query("`Model Number` == @model_number_to_view"))
display(epa_freeze.query("`Model Number` == @model_number_to_view"))
# Out:
#     ENERGY STAR Unique ID   Brand Name   Model Number  \
# 119               2453235  Arctic King  AU83ETWBR1RCM
#
#     Additional Model Information  UPC                  Type  \
# 119                          NaN  NaN  Compact Refrigerator
#
#                                          Product Class Defrost Type Compact  \
# 119  13A - Compact All-Refrigerators - automatic de...    Automatic     Yes
#
#     Built-in Thru the Door Dispenser Ice Maker Counter Depth  Height (in)  \
# 119       No                      No        No            No         66.9
#
#      Width (in)  Capacity (Total Volume) (ft3)  Adjusted Volume (ft3)  \
# 119        24.0                            8.3                    8.3
#
#      Annual Energy Use (kWh/yr)  US Federal Standard (kWh/yr)  \
# 119                         167                         335.0
#
#      Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 119                                              50.0              NaN
#
#     Refrigerant with GWP Connected Functionality Connects Using  \
# 119                  NaN                      No            NaN
#
#     Connected Functionality Tested Communication Standard Application Layer  \
# 119                            NaN                                      NaN
#
#     Direct on-premises Open-standard Based Interconnection  \
# 119                                                NaN
#
#     Date Available On Market Date Certified                Markets  \
# 119               04/11/2023     04/11/2023  United States, Canada
#
#                                    CB Model Identifier  \
# 119  ES_1030337_AU83ETWBR1RCM7_04122023100711_80165973
#
#     Meets ENERGY STAR Most Efficient 2023 Criteria  energy_per_volume
# 119                                            Yes          20.120482
#    ENERGY STAR Unique ID   Brand Name   Model Number  \
# 61               2363422  Arctic King  AU83ETWBR1RCM
# 62               2366125  Arctic King  AU83ETWBR1RCM
#
#    Additional Model Information  UPC             Type  \
# 61                          NaN  NaN  Upright Freezer
# 62                          NaN  NaN  Upright Freezer
#
#                                         Product Class Defrost Type Compact  \
# 61  9 - Upright freezers with automatic defrost wi...    Automatic      No
# 62  9 - Upright freezers with automatic defrost wi...    Automatic      No
#
#    Built-in Thru the Door Dispenser Ice Maker  Capacity (Total Volume) (ft3)  \
# 61       No                      No        No                            8.3
# 62       No                      No        No                            8.3
#
#     Adjusted Volume (ft3)  Annual Energy Use (kWh/yr)  \
# 61                   14.5                         317
# 62                   14.6                         317
#
#     US Federal Standard (kWh/yr)  \
# 61                           353
# 62                           354
#
#     Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 61                                                10              NaN
# 62                                                10              NaN
#
#    Refrigerant with GWP Connected Functionality Date Available On Market  \
# 61                  NaN                      No               07/20/2020
# 62                  NaN                      No               09/21/2020
#
#    Date Certified                Markets  \
# 61     07/23/2020  United States, Canada
# 62     09/11/2020  United States, Canada
#
#                                  CB Model Identifier  \
# 61   ES_1030337_AU83ETWBR1RCM_07242020024616_8776483
# 62  ES_1030337_AU83ETWBR1RCM_09222020021817_5550000_
#
#    Meets ENERGY STAR Most Efficient 2023 Criteria  energy_per_volume
# 61                                             No          21.862069
# 62                                             No          21.712329

# %%
epa_ref['source'] = 'epa_ref'
epa_freeze['source'] = 'epa_freeze'
epa_all = pd.concat([epa_ref, epa_freeze])
epa_all.head(1)
# Out:
#   ENERGY STAR Unique ID   Brand Name Model Number  \
# 0               2369304  Arctic Wind    2ATMW212E
#
#   Additional Model Information  UPC         Type  \
# 0                          NaN  NaN  Top Freezer
#
#                                        Product Class Defrost Type Compact  \
# 0  3 - Refrigerator-freezers - automatic defrost ...    Automatic      No
#
#   Built-in Thru the Door Dispenser Ice Maker Counter Depth  Height (in)  \
# 0       No                      No        No            No         67.0
#
#    Width (in)  Capacity (Total Volume) (ft3)  Adjusted Volume (ft3)  \
# 0        33.0                           21.0                   25.6
#
#    Annual Energy Use (kWh/yr)  US Federal Standard (kWh/yr)  \
# 0                         396                         440.0
#
#    Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 0                                              10.0              NaN
#
#   Refrigerant with GWP Connected Functionality Connects Using  \
# 0                  NaN                      No            NaN
#
#   Connected Functionality Tested Communication Standard Application Layer  \
# 0                            NaN                                      NaN
#
#   Direct on-premises Open-standard Based Interconnection  \
# 0                                                NaN
#
#   Date Available On Market Date Certified                Markets  \
# 0               10/30/2020     11/09/2020  United States, Canada
#
#                            CB Model Identifier  \
# 0  ES_1121980_2ATMW212E_11102020012636_1596636
#
#   Meets ENERGY STAR Most Efficient 2023 Criteria  energy_per_volume   source
# 0                                            Yes           15.46875  epa_ref

# %%
# Duplicate model numbers
model_no_duplicate = epa_all[epa_all.duplicated(subset=['Model Number'], keep=False)]
print(f"There are {len(model_no_duplicate)} duplicate model numbers in epa_all")

# Duplicate model numbers and brand
brand_name_and_model_no_duplicate = epa_all[epa_all.duplicated(["Brand Name", "Model Number"], keep=False)].sort_values(by=['Brand Name', 'Model Number'])
print(f"There are {len(brand_name_and_model_no_duplicate)} duplicate model numbers and brand name combinations in epa_all")
# Out:
# There are 431 duplicate model numbers in epa_all
# There are 373 duplicate model numbers and brand name combinations in epa_all

# %%
def count_epa_duplicates_by(columns_to_check):
    duplicates = epa_all[epa_all.duplicated(subset=columns_to_check, keep=False)]
    print(f"There are {len(duplicates)} duplicates in epa_all with {columns_to_check}\n")
    duplicate_counts = pd.DataFrame(duplicates[columns_to_check].value_counts()).reset_index().rename(columns={0: 'count'})
    return duplicate_counts


# That's a LOT of duplicates....almost half the dataset
count_epa_duplicates_by([
    'Model Number'
])
# Out:
# There are 431 duplicates in epa_all with ['Model Number']
#       Model Number  count
# 0    AU83ETWBR1RCM      3
# 1     GDE21DGK****      3
# 2           EFR323      3
# 3           RFR465      3
# 4       043-0291-4      3
# ..             ...    ...
# 205   GNE25DGK****      2
# 206   GNE25DSK****      2
# 207   GPE12FGK****      2
# 208   GPE12FSK****      2
# 209   XRE18GGA****      2
#
# [210 rows x 2 columns]

# %%
print("Therefore, sometimes the model number is the same but brand name is different. See below.")
epa_all[epa_all['Model Number'] == 'RFR465']
# Out:
# Therefore, sometimes the model number is the same but brand name is different. See below.
#      ENERGY STAR Unique ID Brand Name Model Number  \
# 2820               2300414        RCA       RFR465
# 2821               2301884        RCA       RFR465
# 2822               2331903        RCA       RFR465
#
#                            Additional Model Information  UPC  \
# 2820  Refrigerator,RFR440-C-BLACK,; Refrigerator,RFR...  NaN
# 2821  Refrigerator,RFR440-C-BLACK,; Refrigerator,RFR...  NaN
# 2822                             Refrigerator,RFR465-C,  NaN
#
#                       Type                                    Product Class  \
# 2820  Compact Refrigerator  11A - Compact All-Refrigerator - manual defrost
# 2821  Compact Refrigerator  11A - Compact All-Refrigerator - manual defrost
# 2822  Compact Refrigerator  11A - Compact All-Refrigerator - manual defrost
#
#      Defrost Type Compact Built-in Thru the Door Dispenser Ice Maker  \
# 2820       Manual     Yes       No                      No        No
# 2821       Manual     Yes       No                      No        No
# 2822       Manual     Yes       No                      No        No
#
#      Counter Depth  Height (in)  Width (in)  Capacity (Total Volume) (ft3)  \
# 2820           Yes         32.1        20.1                            4.7
# 2821           Yes         32.0        20.2                            4.6
# 2822           Yes         32.0        20.2                            4.6
#
#       Adjusted Volume (ft3)  Annual Energy Use (kWh/yr)  \
# 2820                    4.7                         224
# 2821                    4.6                         204
# 2822                    4.6                         204
#
#       US Federal Standard (kWh/yr)  \
# 2820                         256.0
# 2821                         255.0
# 2822                         255.0
#
#       Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 2820                                              13.0              NaN
# 2821                                              20.0              NaN
# 2822                                              20.0              NaN
#
#      Refrigerant with GWP Connected Functionality Connects Using  \
# 2820                  NaN                      No            NaN
# 2821                  NaN                      No            NaN
# 2822                  NaN                      No            NaN
#
#      Connected Functionality Tested Communication Standard Application Layer  \
# 2820                             No                                      NaN
# 2821                            NaN                                      NaN
# 2822                            NaN                                      NaN
#
#      Direct on-premises Open-standard Based Interconnection  \
# 2820                                                NaN
# 2821                                                NaN
# 2822                                                NaN
#
#      Date Available On Market Date Certified        Markets  \
# 2820               09/19/2016     07/21/2017  United States
# 2821               07/11/2017     08/01/2017  United States
# 2822               09/14/2018     12/20/2018  United States
#
#                            CB Model Identifier  \
# 2820  ES_1120898_RFR465_07212017140918_5428655
# 2821  ES_1120898_RFR465_08092017133159_6565493
# 2822  ES_1120898_RFR465_12212018104512_6522952
#
#      Meets ENERGY STAR Most Efficient 2023 Criteria  energy_per_volume  \
# 2820                                             No          47.659574
# 2821                                            Yes          44.347826
# 2822                                            Yes          44.347826
#
#        source
# 2820  epa_ref
# 2821  epa_ref
# 2822  epa_ref

# %% [markdown]
# You can explore the `model_no_duplicate` variable to learn more about these. They seem to have unique energy start ids, but the same model number. There are some things to understand and sort out here, but I will move on for now.

# %% [markdown]
# #### How about duplicates in doe_ref?

# %%
doe_ref
# Out:
#           Brand_Name_s__s                   Product_Group_Code_Description_s  \
# 0             Arctic King  (13A.) Compact all-refrigerators - automatic d...
# 1                   Midea                       (18.) Compact chest freezers
# 2                   Midea  (11A.) Compact all-refrigerators - manual defrost
# 3                 Hisense  (13A.) Compact all-refrigerators - automatic d...
# 4                 Hisense  (13A.) Compact all-refrigerators - automatic d...
# ...                   ...                                                ...
# 9321       Black & Decker  (11A.) Compact all-refrigerators - manual defrost
# 9322       Black & Decker  (11A.) Compact all-refrigerators - manual defrost
# 9323  Professional Series  (11A.) Compact all-refrigerators - manual defrost
# 9324               Golden  (3.) Refrigerator-freezers - automatic defrost...
# 9325               AVANTI  (3.) Refrigerator-freezers - automatic defrost...
#
#      Basic_Model_Number_m Individual_Model_Number_Covered_by_Basic_Model_m  \
# 0            HS-60LN(SNZ)                                       ARM17A5ABB
# 1          HS-259CN(SNZK)                                       MRC07M7AWW
# 2         HS-121LN(S4NZ1)                                       MRM33S9ASL
# 3      BC-94DJ1NA1/HC1(Q)                                        RC33A1GWE
# 4           BC-122/HC1(H)                                      LMS044M6RBE
# ...                   ...                                              ...
# 9321               KS-48R                                          BCRK17B
# 9322               KS-48R                                          BCRK17W
# 9323               KS-91R                                     PS-RF739-I6A
# 9324               BCD290                                           BCD290
# 9325            FF1011D1B                                        FF1011D1B
#
#       Total_Adjusted_Volume__Cubic_Feet__d  \
# 0                                      1.7
# 1                                     12.3
# 2                                      3.3
# 3                                      3.3
# 4                                      4.4
# ...                                    ...
# 9321                                   1.7
# 9322                                   1.7
# 9323                                   3.2
# 9324                                  12.1
# 9325                                  12.1
#
#       Annual_Energy_Use__Kilowatt_Hours_Year__d  \
# 0                                         246.0
# 1                                         225.0
# 2                                         220.0
# 3                                         260.0
# 4                                         269.0
# ...                                         ...
# 9321                                      232.0
# 9322                                      232.0
# 9323                                      219.0
# 9324                                      331.0
# 9325                                      331.0
#
#       Total_Refrigerated_Volume__ft3__d  \
# 0                                   1.7
# 1                                   7.0
# 2                                   3.3
# 3                                   3.3
# 4                                   4.4
# ...                                 ...
# 9321                                1.7
# 9322                                1.7
# 9323                                3.2
# 9324                               10.1
# 9325                               10.1
#
#      Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s  \
# 0                                                    No
# 1                                                    No
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 9321                                                 No
# 9322                                                 No
# 9323                                                 No
# 9324                                                 No
# 9325                                                 No
#
#      Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s  \
# 0                                                    No
# 1                                                    No
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 9321                                                 No
# 9322                                                 No
# 9323                                                 No
# 9324                                                 No
# 9325                                                 No
#
#                         Link_to_FTC_EnergyGuide_Label_s code  \
# 0     https://wx1.sinaimg.cn/mw2000/7db66851ly1h1861...  13A
# 1                                 By annual report date   18
# 2                                 By annual report date  11A
# 3     https://www.hisense-canada.com/en/home-applian...  13A
# 4     https://www.hisense-canada.com/en/home-applian...  13A
# ...                                                 ...  ...
# 9321                              By annual report date  11A
# 9322                              By annual report date  11A
# 9323                              By annual report date  11A
# 9324                              By annual report date    3
# 9325                              By annual report date    3
#
#       energy_per_volume same_energy_use
# 0            144.705882            True
# 1             18.292683            True
# 2             66.666667            True
# 3             78.787879            True
# 4             61.136364            True
# ...                 ...             ...
# 9321         136.470588            True
# 9322         136.470588            True
# 9323          68.437500           False
# 9324          27.355372            True
# 9325          27.355372            None
#
# [9162 rows x 13 columns]

# %%
# While there are 9326 rows, each with it's own model number, they're not all unique
print(doe_ref.Individual_Model_Number_Covered_by_Basic_Model_m.nunique())
# Out:
# 5471

# %%
# Model number columns are never blank
display(doe_ref.query("Individual_Model_Number_Covered_by_Basic_Model_m.isna()"))
display(doe_ref.query("Basic_Model_Number_m.isna()"))
# Out:
# Empty DataFrame
# Columns: [Brand_Name_s__s, Product_Group_Code_Description_s, Basic_Model_Number_m, Individual_Model_Number_Covered_by_Basic_Model_m, Total_Adjusted_Volume__Cubic_Feet__d, Annual_Energy_Use__Kilowatt_Hours_Year__d, Total_Refrigerated_Volume__ft3__d, Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s, Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s, Link_to_FTC_EnergyGuide_Label_s, code, energy_per_volume, same_energy_use]
# Index: []
# Empty DataFrame
# Columns: [Brand_Name_s__s, Product_Group_Code_Description_s, Basic_Model_Number_m, Individual_Model_Number_Covered_by_Basic_Model_m, Total_Adjusted_Volume__Cubic_Feet__d, Annual_Energy_Use__Kilowatt_Hours_Year__d, Total_Refrigerated_Volume__ft3__d, Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s, Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s, Link_to_FTC_EnergyGuide_Label_s, code, energy_per_volume, same_energy_use]
# Index: []

# %%
# but they are sometimes duplicated...see columns below

def count_doe_duplicates_by(columns_to_check):
    duplicates = doe_ref[doe_ref.duplicated(subset=columns_to_check, keep=False)]
    print(f"There are {len(duplicates)} duplicates in doe_ref with {columns_to_check}\n")
    duplicate_counts = pd.DataFrame(duplicates[columns_to_check].value_counts()).reset_index().rename(columns={0: 'count'})
    return duplicate_counts


# That's a LOT of duplicates....almost half the dataset
count_doe_duplicates_by([
    'Basic_Model_Number_m'
])
# Out:
# There are 6834 duplicates in doe_ref with ['Basic_Model_Number_m']
#      Basic_Model_Number_m  count
# 0                  FAB10U     50
# 1                  FAB28U     50
# 2               BCD-95ANB     42
# 3                FAB28U_1     34
# 4                BC-50DAN     33
# ...                   ...    ...
# 1727            7w7p10-26      2
# 1728            7w7p40-26      2
# 1729               7w7t42      2
# 1730            7w7t42-01      2
# 1731            ZPJ-170-E      2
#
# [1732 rows x 2 columns]

# %%
# If we look at duplicates across both types of model numbers, we have significantly fewer...but what does that mean?

count_doe_duplicates_by([
    # 'Brand_Name_s__s', # note if you remove this, they increase...so we have some duplicate model numbers with different brand names
    'Basic_Model_Number_m', 
    'Individual_Model_Number_Covered_by_Basic_Model_m'
])
# Out:
# There are 205 duplicates in doe_ref with ['Basic_Model_Number_m', 'Individual_Model_Number_Covered_by_Basic_Model_m']
#       Basic_Model_Number_m Individual_Model_Number_Covered_by_Basic_Model_m  \
# 0                     DZ50                                        EX PRO 50
# 1                   FLOW55                                            CRW55
# 2                     CR50                                             CR32
# 3                     CR50                                             CR40
# 4                     CR50                                             CR42
# ..                     ...                                              ...
# 86               BCD-95ANB                                 EFR840-MINT-6COM
# 87       BCD-560WPZ/HC1(H)                                      HRQ215N6BVD
# 88  BCD-490WP1BF1S3/HC1(H)                                      MRM198N6T*E
# 89       BCD-450WYZ/HC1(H)                                      HRB171N6B*E
# 90                     X50                                              X50
#
#     count
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
# ..    ...
# 86      2
# 87      2
# 88      2
# 89      2
# 90      2
#
# [91 rows x 3 columns]

# %%
# # Explore a particular duplicate in this cell
# model_number_to_view = 'FAB28U'
# doe_ref.query("Basic_Model_Number_m == @model_number_to_view")

# %% [markdown]
# # Finding and separating out the overlap in EPA and DOE data

# %%
# same as my epa_all above or as Minju's epa_ref_freeze
epa = pd.concat([epa_ref, epa_freeze])\
    .assign(
        code = lambda x: x['Product Class'].str.split(" -").str[0], # since product codes don't exist on epa_freeze, we have to split them out of "Product Class"
        
        # standardize some columns across both datasets
        adj_volume = lambda x: x['Adjusted Volume (ft3)'].astype(float),
        annual_energy_use = lambda x: x['Annual Energy Use (kWh/yr)'].astype(float),
        energy_per_volume = lambda x: x['annual_energy_use'] / x['adj_volume']
    )

epa.sample(3)
# Out:
#      ENERGY STAR Unique ID   Brand Name  Model Number  \
# 306                2393856    Criterion   CTMR183**#*
# 1742               2401322   KitchenAid  KRQC506M****
# 59                 2333368  Arctic King  ARU030S1ARWW
#
#                            Additional Model Information           UPC  \
# 306   ,,1st "*" Vendor code : A-Z ,2nd "*" Vendor co...           NaN
# 1742                                                NaN  883049643915
# 59                                                  NaN  817986026555
#
#                 Type                                      Product Class  \
# 306      Top Freezer  3 - Refrigerator-freezers - automatic defrost ...
# 1742  Bottom Freezer  5I - Refrigerator-freezers - automatic defrost...
# 59           Compact  16 - Compact upright freezers with manual defrost
#
#      Defrost Type Compact Built-in Thru the Door Dispenser Ice Maker  \
# 306     Automatic      No       No                      No        No
# 1742    Automatic      No       No                      No       Yes
# 59         Manual     Yes       No                      No        No
#
#      Counter Depth  Height (in)  Width (in)  Capacity (Total Volume) (ft3)  \
# 306             No         66.3        29.9                           18.3
# 1742           Yes         69.5        35.8                           19.4
# 59             NaN          NaN         NaN                            3.0
#
#       Adjusted Volume (ft3)  Annual Energy Use (kWh/yr)  \
# 306                    22.2                         370
# 1742                   25.1                         569
# 59                      5.3                         240
#
#       US Federal Standard (kWh/yr)  \
# 306                          413.0
# 1742                         623.0
# 59                           272.0
#
#       Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 306                                               10.0           R-600a
# 1742                                              10.0           R-600a
# 59                                                12.0              NaN
#
#             Refrigerant with GWP Connected Functionality Connects Using  \
# 306   R-600a (GWP:3 | Lower GWP)                      No            NaN
# 1742  R-600a (GWP:3 | Lower GWP)                      No            NaN
# 59                           NaN                      No            NaN
#
#      Connected Functionality Tested Communication Standard Application Layer  \
# 306                             NaN                                      NaN
# 1742                            NaN                                      NaN
# 59                              NaN                                      NaN
#
#      Direct on-premises Open-standard Based Interconnection  \
# 306                                                 NaN
# 1742                                                NaN
# 59                                                  NaN
#
#      Date Available On Market Date Certified                Markets  \
# 306                02/25/2022     03/17/2022          United States
# 1742               08/31/2022     09/07/2022  United States, Canada
# 59                 10/09/2021     10/15/2021  United States, Canada
#
#                                   CB Model Identifier  \
# 306    ES_1062598_CTMR183**#*_031720222340810_8590264
# 1742  ES_0022856_KRQC506M****_09092022020348_80141283
# 59     ES_1030337_ARU030S1ARWW_02122019062527_2727762
#
#      Meets ENERGY STAR Most Efficient 2023 Criteria  energy_per_volume  \
# 306                                             Yes          16.666667
# 1742                                             No          22.669323
# 59                                               No          45.283019
#
#           source code  adj_volume  annual_energy_use
# 306      epa_ref    3        22.2              370.0
# 1742     epa_ref   5I        25.1              569.0
# 59    epa_freeze   16         5.3              240.0

# %%
doe = doe_ref.assign(
    source='doe',

    # standardize some columns across both datasets
    adj_volume = lambda x: x['Total_Adjusted_Volume__Cubic_Feet__d'].astype(float),
    annual_energy_use = lambda x: x['Annual_Energy_Use__Kilowatt_Hours_Year__d'].astype(float),
    energy_per_volume = lambda x: x['annual_energy_use'] / x['adj_volume']
)

doe.head(3)
# Out:
#   Brand_Name_s__s                   Product_Group_Code_Description_s  \
# 0     Arctic King  (13A.) Compact all-refrigerators - automatic d...
# 1           Midea                       (18.) Compact chest freezers
# 2           Midea  (11A.) Compact all-refrigerators - manual defrost
#
#   Basic_Model_Number_m Individual_Model_Number_Covered_by_Basic_Model_m  \
# 0         HS-60LN(SNZ)                                       ARM17A5ABB
# 1       HS-259CN(SNZK)                                       MRC07M7AWW
# 2      HS-121LN(S4NZ1)                                       MRM33S9ASL
#
#    Total_Adjusted_Volume__Cubic_Feet__d  \
# 0                                   1.7
# 1                                  12.3
# 2                                   3.3
#
#    Annual_Energy_Use__Kilowatt_Hours_Year__d  \
# 0                                      246.0
# 1                                      225.0
# 2                                      220.0
#
#    Total_Refrigerated_Volume__ft3__d  \
# 0                                1.7
# 1                                7.0
# 2                                3.3
#
#   Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
#
#   Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
#
#                      Link_to_FTC_EnergyGuide_Label_s code  energy_per_volume  \
# 0  https://wx1.sinaimg.cn/mw2000/7db66851ly1h1861...  13A         144.705882
# 1                              By annual report date   18          18.292683
# 2                              By annual report date  11A          66.666667
#
#   same_energy_use source  adj_volume  annual_energy_use
# 0            True    doe         1.7              246.0
# 1            True    doe        12.3              225.0
# 2            True    doe         3.3              220.0

# %% [markdown]
# We want to dedupe `epa_ref_freeze` and `doe_ref` on their model numbers after replacing `*` and `#` with wildcards on both. We expect doe to be a superset of epa.

# %%
display(epa.head(2))
display(doe.head(2))
# Out:
#   ENERGY STAR Unique ID   Brand Name Model Number  \
# 0               2369304  Arctic Wind    2ATMW212E
# 1               2397747  Arctic Wind    2AW1BF26A
#
#   Additional Model Information                        UPC  \
# 0                          NaN                        NaN
# 1                 ,2AW1SLF26A,  850012484240;850012484370
#
#                    Type                                      Product Class  \
# 0           Top Freezer  3 - Refrigerator-freezers - automatic defrost ...
# 1  Compact Refrigerator    11A - Compact All-Refrigerator - manual defrost
#
#   Defrost Type Compact Built-in Thru the Door Dispenser Ice Maker  \
# 0    Automatic      No       No                      No        No
# 1       Manual     Yes       No                      No        No
#
#   Counter Depth  Height (in)  Width (in)  Capacity (Total Volume) (ft3)  \
# 0            No         67.0        33.0                           21.0
# 1            No         27.4        17.5                            2.6
#
#    Adjusted Volume (ft3)  Annual Energy Use (kWh/yr)  \
# 0                   25.6                         396
# 1                    2.6                         215
#
#    US Federal Standard (kWh/yr)  \
# 0                         440.0
# 1                         239.0
#
#    Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 0                                              10.0              NaN
# 1                                              10.0              NaN
#
#   Refrigerant with GWP Connected Functionality Connects Using  \
# 0                  NaN                      No            NaN
# 1                  NaN                      No            NaN
#
#   Connected Functionality Tested Communication Standard Application Layer  \
# 0                            NaN                                      NaN
# 1                            NaN                                      NaN
#
#   Direct on-premises Open-standard Based Interconnection  \
# 0                                                NaN
# 1                                                NaN
#
#   Date Available On Market Date Certified                Markets  \
# 0               10/30/2020     11/09/2020  United States, Canada
# 1               08/15/2022     06/23/2022  United States, Canada
#
#                            CB Model Identifier  \
# 0  ES_1121980_2ATMW212E_11102020012636_1596636
# 1  ES_1121980_2AW1BF26A_06202022134236_2692056
#
#   Meets ENERGY STAR Most Efficient 2023 Criteria  energy_per_volume   source  \
# 0                                            Yes          15.468750  epa_ref
# 1                                             No          82.692308  epa_ref
#
#   code  adj_volume  annual_energy_use
# 0    3        25.6              396.0
# 1  11A         2.6              215.0
#   Brand_Name_s__s                   Product_Group_Code_Description_s  \
# 0     Arctic King  (13A.) Compact all-refrigerators - automatic d...
# 1           Midea                       (18.) Compact chest freezers
#
#   Basic_Model_Number_m Individual_Model_Number_Covered_by_Basic_Model_m  \
# 0         HS-60LN(SNZ)                                       ARM17A5ABB
# 1       HS-259CN(SNZK)                                       MRC07M7AWW
#
#    Total_Adjusted_Volume__Cubic_Feet__d  \
# 0                                   1.7
# 1                                  12.3
#
#    Annual_Energy_Use__Kilowatt_Hours_Year__d  \
# 0                                      246.0
# 1                                      225.0
#
#    Total_Refrigerated_Volume__ft3__d  \
# 0                                1.7
# 1                                7.0
#
#   Is_the_Certification_for_this_Basic_Model_Based_on_a_Waiver_of_DOE_s_Test_Procedure_Requirements__s  \
# 0                                                 No
# 1                                                 No
#
#   Is_the_Certification_based_upon_any_Exception_Relief_from_an_Applicable_Standard_by_DOE_s_Office_of_Hearing_and_Appeals__s  \
# 0                                                 No
# 1                                                 No
#
#                      Link_to_FTC_EnergyGuide_Label_s code  energy_per_volume  \
# 0  https://wx1.sinaimg.cn/mw2000/7db66851ly1h1861...  13A         144.705882
# 1                              By annual report date   18          18.292683
#
#   same_energy_use source  adj_volume  annual_energy_use
# 0            True    doe         1.7              246.0
# 1            True    doe        12.3              225.0

# %%
# Find all models from the EPA are in the DOE, using REGEX
def regexify_model_number(model_number):
    model_number_regex = re.sub(r'\*', '.', model_number)
    model_number_regex = re.sub(r'\#', '.', model_number_regex)
    return model_number_regex

epa['regexed_model_no'] = epa['Model Number'].apply(regexify_model_number)
doe['regexed_model_no'] = doe['Individual_Model_Number_Covered_by_Basic_Model_m'].apply(regexify_model_number)

# %% [markdown]
# Each dataframe now has a `regexed_model_no` column. Here are some models that have wildcards in the model number in both dataframes.

# %%
epa_regexes = epa[['regexed_model_no']] 
epa_regexes['source'] = 'epa'
display(epa_regexes.sample(3))

doe_regexes = doe[['regexed_model_no']]
doe_regexes['source'] = 'doe'
display(doe_regexes.sample(3))
# Out:
#      regexed_model_no source
# 2570          2P1BF26    epa
# 1073      GLR33MWEE02    epa
# 341      CVE28DP.NC..    epa
#      regexed_model_no source
# 6212    UHRE518-IG01A    doe
# 1353       BKI36Bi-LS    doe
# 7559       MBL1957DE.    doe

# %% [markdown]
# now we will make join tables for each

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

def matches_from_doe(model_number_pattern):
    models = set(doe['Individual_Model_Number_Covered_by_Basic_Model_m'])
    # get all models that match the pattern
    matches = [(str(model_number_pattern), model) for model in models if re.match(model_number_pattern, model)]
    return pd.DataFrame(matches, columns=['epa_regex', 'Individual_Model_Number_Covered_by_Basic_Model_m'])
    
epa_regex_join = pd.concat(epa_regexes.regexed_model_no.progress_apply(matches_from_doe).tolist())
epa_regex_join
# Out:
#   0%|          | 0/3846 [00:00<?, ?it/s]
#        epa_regex Individual_Model_Number_Covered_by_Basic_Model_m
# 0        AR17T0W                                          AR17T0W
# 0        AR17T1B                                          AR17T1B
# 0        AR2406W                                          AR2406W
# 0        AR24T3S                                          AR24T3S
# 0        AR24T3S                                          AR24T3S
# ..           ...                                              ...
# 0      CUF-301BK                                        CUF-301BK
# 0      CUF-301SS                                        CUF-301SS
# 0      UDF-139SS                                        UDF-139SS
# 0    W.FU021A.E.                                      W*FU021A*E#
# 0   WRSR036H..E.                                     WRSR036H**E#
#
# [2617 rows x 2 columns]

# %%
def matches_from_epa(model_number_pattern):
    models = set(epa['Model Number'])
    # get all models that match the pattern
    matches = [(str(model_number_pattern), model) for model in models if re.match(model_number_pattern, model)]
    return pd.DataFrame(matches, columns=['doe_regex', 'Model Number'])
    
doe_regex_join = pd.concat(doe_regexes.regexed_model_no.progress_apply(matches_from_epa).tolist())
doe_regex_join
# Out:
#   0%|          | 0/9162 [00:00<?, ?it/s]
#         doe_regex   Model Number
# 0      ARM17A5ABB     ARM17A5ABB
# 0      MRC07M7AWW     MRC07M7AWW
# 0      MRM33S9ASL     MRM33S9ASL
# 0     LMS044M6RBE    LMS044M6RBE
# 0         7931...        7931***
# ..            ...            ...
# 0       CTMR74C1B      CTMR74C1B
# 0   VBFR1800ESE-C  VBFR1800ESE-C
# 0         BCRK43B        BCRK43B
# 0         BCRK32B        BCRK32B
# 0         BCRK17B        BCRK17B
#
# [3471 rows x 2 columns]

# %% [markdown]
# now if you want all of the items in the epa database that are also in the doe database, you'll want to join through both of these, since you can join by an epa ID matching a doe pattern, or a doe id matching an epa pattern...

# %%
# (we think) ...this is assuming our other assumptions about these columns like what they mean, things about duplicates, etc all hold...
# which I have some doubts about...
epa['exists_in_other_db'] = epa.progress_apply(lambda row: 
                                                    row['Model Number'] in doe_regex_join['Model Number'].values or 
                                                    row['regexed_model_no'] in epa_regex_join['epa_regex'].values, 
                                               axis=1)
epa.exists_in_other_db.value_counts()
# Out:
#   0%|          | 0/3846 [00:00<?, ?it/s]
# True     2259
# False    1587
# Name: exists_in_other_db, dtype: int64

# %%
doe['exists_in_other_db'] = doe.progress_apply(lambda row: 
                                                    row['regexed_model_no'] in doe_regex_join['doe_regex'].values or 
                                                    row['Individual_Model_Number_Covered_by_Basic_Model_m'] in epa_regex_join['Individual_Model_Number_Covered_by_Basic_Model_m'].values,
                                               axis=1)
                                             
doe.exists_in_other_db.value_counts()
# Out:
#   0%|          | 0/9162 [00:00<?, ?it/s]
# False    5597
# True     3565
# Name: exists_in_other_db, dtype: int64

# %%
epa # see exists_in_other_db column to filter by the ones we think exist in the other db...
# Out:
#     ENERGY STAR Unique ID   Brand Name  Model Number  \
# 0                 2369304  Arctic Wind     2ATMW212E
# 1                 2397747  Arctic Wind     2AW1BF26A
# 2                 2393669  Arctic Wind    2AW1SLF44A
# 3                 2370277  Arctic Wind      ABM*171E
# 4                 2370276  Arctic Wind     ABM*171E*
# ..                    ...          ...           ...
# 397               2235482      Whynter     UDF-138DW
# 398               2328022      Whynter     UDF-139SS
# 399               2386091        WINIA   W*FU021A*E#
# 400               2389273        WINIA  WRSR036H**E#
# 401               2453178        Zline     RBCFVL-18
#
#                           Additional Model Information  \
# 0                                                  NaN
# 1                                         ,2AW1SLF26A,
# 2                                                  NaN
# 3    ,,The symbol *, maybe replaced by A-Z, means d...
# 4    ,,The symbol *, maybe replaced by A-Z, means d...
# ..                                                 ...
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400  ,,First "*" means that Color code 1: A-Z -\tSe...
# 401                                        ,RBCFVR-18,
#
#                            UPC                  Type  \
# 0                          NaN           Top Freezer
# 1    850012484240;850012484370  Compact Refrigerator
# 2                 850012484400  Compact Refrigerator
# 3                          NaN        Bottom Freezer
# 4                          NaN        Bottom Freezer
# ..                         ...                   ...
# 397                        NaN       Upright Freezer
# 398               852749006665       Upright Freezer
# 399                        NaN       Upright Freezer
# 400                        NaN               Compact
# 401  195948020989;195948021962       Upright Freezer
#
#                                          Product Class Defrost Type Compact  \
# 0    3 - Refrigerator-freezers - automatic defrost ...    Automatic      No
# 1      11A - Compact All-Refrigerator - manual defrost       Manual     Yes
# 2      11A - Compact All-Refrigerator - manual defrost       Manual     Yes
# 3    5 - Refrigerator-freezers - automatic defrost ...    Automatic      No
# 4    5 - Refrigerator-freezers - automatic defrost ...    Automatic      No
# ..                                                 ...          ...     ...
# 397  9 - Upright freezers with automatic defrost wi...    Automatic      No
# 398  9 - Upright freezers with automatic defrost wi...    Automatic      No
# 399  9 - Upright freezers with automatic defrost wi...    Automatic      No
# 400  17 - Compact upright freezers with automatic d...    Automatic     Yes
# 401  9I-BI - Built-In upright freezers with automat...    Automatic      No
#
#     Built-in Thru the Door Dispenser Ice Maker Counter Depth  Height (in)  \
# 0         No                      No        No            No         67.0
# 1         No                      No        No            No         27.4
# 2         No                      No        No            No         33.1
# 3         No                      No        No            No         69.1
# 4         No                      No        No            No         69.1
# ..       ...                     ...       ...           ...          ...
# 397       No                      No        No           NaN          NaN
# 398       No                      No        No           NaN          NaN
# 399       No                      No        No           NaN          NaN
# 400       No                      No        No           NaN          NaN
# 401      Yes                     Yes       Yes           NaN          NaN
#
#      Width (in)  Capacity (Total Volume) (ft3)  Adjusted Volume (ft3)  \
# 0          33.0                           21.0                   25.6
# 1          17.5                            2.6                    2.6
# 2          18.7                            4.4                    4.4
# 3          31.3                           17.1                   20.9
# 4          31.3                           17.1                   20.9
# ..          ...                            ...                    ...
# 397         NaN                           13.8                   24.3
# 398         NaN                           13.8                   24.3
# 399         NaN                           20.8                   36.7
# 400         NaN                            3.6                    6.3
# 401         NaN                            8.7                   15.3
#
#      Annual Energy Use (kWh/yr)  US Federal Standard (kWh/yr)  \
# 0                           396                         440.0
# 1                           215                         239.0
# 2                           228                         254.0
# 3                           451                         502.0
# 4                           451                         502.0
# ..                          ...                           ...
# 397                         391                         438.0
# 398                         394                         438.0
# 399                         489                         545.0
# 400                         266                         416.0
# 401                         452                         496.0
#
#      Percent Less Energy Use than US Federal Standard Refrigerant Type  \
# 0                                                10.0              NaN
# 1                                                10.0              NaN
# 2                                                10.0              NaN
# 3                                                10.0           R-600a
# 4                                                10.0           R-600a
# ..                                                ...              ...
# 397                                              11.0              NaN
# 398                                              10.0              NaN
# 399                                              10.0           R-600a
# 400                                              36.0           R-600a
# 401                                              11.0              NaN
#
#            Refrigerant with GWP Connected Functionality Connects Using  \
# 0                           NaN                      No            NaN
# 1                           NaN                      No            NaN
# 2                           NaN                      No            NaN
# 3    R-600a (GWP:3 | Lower GWP)                      No            NaN
# 4    R-600a (GWP:3 | Lower GWP)                      No            NaN
# ..                          ...                     ...            ...
# 397                         NaN                      No            NaN
# 398                         NaN                      No            NaN
# 399  R-600a (GWP:3 | Lower GWP)                      No            NaN
# 400  R-600a (GWP:3 | Lower GWP)                      No            NaN
# 401                         NaN                      No            NaN
#
#     Connected Functionality Tested Communication Standard Application Layer  \
# 0                              NaN                                      NaN
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
# 3                              NaN                                      NaN
# 4                              NaN                                      NaN
# ..                             ...                                      ...
# 397                            NaN                                      NaN
# 398                            NaN                                      NaN
# 399                            NaN                                      NaN
# 400                            NaN                                      NaN
# 401                            NaN                                      NaN
#
#     Direct on-premises Open-standard Based Interconnection  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
#
#     Date Available On Market Date Certified                Markets  \
# 0                 10/30/2020     11/09/2020  United States, Canada
# 1                 08/15/2022     06/23/2022  United States, Canada
# 2                 04/15/2022     03/08/2022  United States, Canada
# 3                 11/23/2020     11/25/2020  United States, Canada
# 4                 11/23/2020     11/25/2020  United States, Canada
# ..                       ...            ...                    ...
# 397               03/27/2015     03/27/2015  United States, Canada
# 398               10/15/2018     02/03/2023  United States, Canada
# 399               03/10/2021     10/14/2021          United States
# 400               12/10/2021     12/13/2021  United States, Canada
# 401               03/30/2023     04/11/2023  United States, Canada
#
#                                  CB Model Identifier  \
# 0        ES_1121980_2ATMW212E_11102020012636_1596636
# 1        ES_1121980_2AW1BF26A_06202022134236_2692056
# 2       ES_1121980_2AW1SLF44A_03012022142251_5311380
# 3        ES_1121980_ABM*171E_112520200126738_9572853
# 4        ES_1121980_ABM*171E*_11252020012627_7795251
# ..                                               ...
# 397     ES_1122240_UDF-138DW_03312015031110_70027805
# 398      ES_1122240_UDF-139SS_10182018022602_9562210
# 399   ES_1108205_W*FU021A*E#_101220210200432_3338165
# 400  ES_1108205_WRSR036H**E#_112620210207984_9542170
# 401      ES_1145610_RBCFVL-18_03292023132335_5841638
#
#     Meets ENERGY STAR Most Efficient 2023 Criteria  energy_per_volume  \
# 0                                              Yes          15.468750
# 1                                               No          82.692308
# 2                                               No          51.818182
# 3                                               No          21.578947
# 4                                               No          21.578947
# ..                                             ...                ...
# 397                                             No          16.090535
# 398                                             No          16.213992
# 399                                             No          13.324251
# 400                                            Yes          42.222222
# 401                                             No          29.542484
#
#          source   code  adj_volume  annual_energy_use regexed_model_no  \
# 0       epa_ref      3        25.6              396.0        2ATMW212E
# 1       epa_ref    11A         2.6              215.0        2AW1BF26A
# 2       epa_ref    11A         4.4              228.0       2AW1SLF44A
# 3       epa_ref      5        20.9              451.0         ABM.171E
# 4       epa_ref      5        20.9              451.0        ABM.171E.
# ..          ...    ...         ...                ...              ...
# 397  epa_freeze      9        24.3              391.0        UDF-138DW
# 398  epa_freeze      9        24.3              394.0        UDF-139SS
# 399  epa_freeze      9        36.7              489.0      W.FU021A.E.
# 400  epa_freeze     17         6.3              266.0     WRSR036H..E.
# 401  epa_freeze  9I-BI        15.3              452.0        RBCFVL-18
#
#      exists_in_other_db
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ..                  ...
# 397               False
# 398                True
# 399                True
# 400                True
# 401               False
#
# [3846 rows x 39 columns]

# %% [markdown]
# # For Publication

# %%
doe_minus_epa = doe[~doe['exists_in_other_db']]

# %%
# plot energy_per_volume
display(doe_minus_epa['energy_per_volume'].hist(bins=100, figsize=(16, 4))) # blue
display(epa['energy_per_volume'].hist(bins=100, figsize=(16, 4))) # orange

# add title
plt.title('Energy per Volume (kWh/yr/ft3)')
# Out:
# <AxesSubplot: >
# <AxesSubplot: >
# Text(0.5, 1.0, 'Energy per Volume (kWh/yr/ft3)')

# %%
epa_compact = epa[epa['Compact']=="Yes"]
epa_standard = epa[epa['Compact']=="No"]

# %%
doe_mepa_compact = doe_minus_epa[doe_minus_epa['Product_Group_Code_Description_s'].str.lower().str.contains('compact')]
doe_mepa_standard = doe_minus_epa[~doe_minus_epa['Product_Group_Code_Description_s'].str.lower().str.contains('compact')]

# %%
display(len(epa_compact)/len(epa))
display(len(doe_mepa_compact)/len(doe_minus_epa))
# Out:
# 0.43551742069682786
# 0.34250491334643557

# %%
display(len(epa_standard)/len(epa))
display(len(doe_mepa_standard)/len(doe_minus_epa))
# Out:
# 0.5644825793031721
# 0.6574950866535644

# %% [markdown]
# ## ALL

# %%
print(f"The average energy per volume for EPA refrigerators is {epa.energy_per_volume.mean():.2f} kWh/yr/ft3")
display(epa.energy_per_volume.describe())

print(f"The average energy per volume for DOE refrigerators is {doe_minus_epa.energy_per_volume.mean():.2f} kWh/yr/ft3")
display(doe_minus_epa.energy_per_volume.describe())
# Out:
# The average energy per volume for EPA refrigerators is 42.89 kWh/yr/ft3
# count    3846.000000
# mean       42.885124
# std        31.433421
# min         8.324607
# 25%        20.391304
# 50%        25.149701
# 75%        61.484375
# max       241.000000
# Name: energy_per_volume, dtype: float64
# The average energy per volume for DOE refrigerators is 36.48 kWh/yr/ft3
# count    5597.000000
# mean       36.476545
# std        28.657688
# min         9.726027
# 25%        20.368421
# 50%        24.349206
# 75%        43.181818
# max       181.333333
# Name: energy_per_volume, dtype: float64

# %%
# Plot energy per volume for standard refrigerators
display(doe_minus_epa['energy_per_volume'].plot.kde(figsize=(16, 8), color='red', alpha=0.4, label='DOE'))
display(epa['energy_per_volume'].plot.kde(figsize=(16, 8), color='green', alpha=0.4, label='EPA'))

# Add title
plt.title('Energy per Volume (kWh/yr/ft3) for Refrigerators')

# Add legend
plt.legend()

# Add average lines
plt.axvline(doe_minus_epa.energy_per_volume.mean(), color='red', linestyle='dashed', linewidth=1)
plt.axvline(epa.energy_per_volume.mean(), color='green', linestyle='dashed', linewidth=1)
# Out:
# <AxesSubplot: ylabel='Density'>
# <AxesSubplot: ylabel='Density'>

# %%
more_energy_than_doe_average = epa[epa.energy_per_volume > doe_minus_epa.energy_per_volume.mean()]['Model Number'].count()/epa['Model Number'].count()

print(f"{more_energy_than_doe_average:.2%} of EPA refrigerators use more energy per volume than the average DOE refrigerator.")
# Out:
# 41.24% of EPA refrigerators use more energy per volume than the average DOE refrigerator.

# %% [markdown]
# ## Standard

# %%
print(f"The average energy per volume for EPA standard refrigerators is {epa_standard.energy_per_volume.mean():.2f} kWh/yr/ft3")
display(epa_standard.energy_per_volume.describe())

print(f"The average energy per volume for DOE standard refrigerators is {doe_mepa_standard.energy_per_volume.mean():.2f} kWh/yr/ft3")
display(doe_mepa_standard.energy_per_volume.describe())
# Out:
# The average energy per volume for EPA standard refrigerators is 21.36 kWh/yr/ft3
# count    2171.000000
# mean       21.361876
# std         4.880687
# min         8.324607
# 25%        18.061224
# 50%        21.232227
# 75%        23.864542
# max        80.666667
# Name: energy_per_volume, dtype: float64
# The average energy per volume for DOE standard refrigerators is 22.46 kWh/yr/ft3
# count    3680.000000
# mean       22.461089
# std         3.839059
# min        10.758808
# 25%        19.323671
# 50%        22.500000
# 75%        25.224490
# max        49.468085
# Name: energy_per_volume, dtype: float64

# %%
# Plot energy per volume for standard refrigerators
display(doe_mepa_standard['energy_per_volume'].plot.kde(figsize=(16, 8), color='red', alpha=0.4, label='DOE'))
display(epa_standard['energy_per_volume'].plot.kde(figsize=(16, 8), color='green', alpha=0.4, label='EPA'))

# Add title
plt.title('Energy per Volume (kWh/yr/ft3) for Standard Refrigerators')

# Add legend
plt.legend()

# Add average lines
plt.axvline(doe_mepa_standard.energy_per_volume.mean(), color='red', linestyle='dashed', linewidth=1)
plt.axvline(epa_standard.energy_per_volume.mean(), color='green', linestyle='dashed', linewidth=1)
# Out:
# <AxesSubplot: ylabel='Density'>
# <AxesSubplot: ylabel='Density'>

# %%
more_energy_than_doe_average_standard = epa_standard[epa_standard.energy_per_volume > doe_mepa_standard.energy_per_volume.mean()]['Model Number'].count()/epa_standard['Model Number'].count()

print(f"{more_energy_than_doe_average_standard:.2%} of EPA standard refrigerators use more energy per volume than the average DOE standard refrigerator.")
# Out:
# 33.12% of EPA standard refrigerators use more energy per volume than the average DOE standard refrigerator.

# %% [markdown]
# ## Compact

# %%
print(f"The average energy per volume for EPA compact refrigerators is {epa_compact.energy_per_volume.mean():.2f} kWh/yr/ft3")
display(epa_compact.energy_per_volume.describe())

print(f"The average energy per volume for DOE compact refrigerators is {doe_mepa_compact.energy_per_volume.mean():.2f} kWh/yr/ft3")
display(doe_mepa_compact.energy_per_volume.describe())
# Out:
# The average energy per volume for EPA compact refrigerators is 70.78 kWh/yr/ft3
# count    1675.000000
# mean       70.781823
# std        29.310621
# min        16.097561
# 25%        51.363636
# 50%        66.666667
# 75%        82.820513
# max       241.000000
# Name: energy_per_volume, dtype: float64
# The average energy per volume for DOE compact refrigerators is 63.38 kWh/yr/ft3
# count    1917.000000
# mean       63.381542
# std        35.620187
# min         9.726027
# 25%        34.693878
# 50%        59.523810
# 75%        85.000000
# max       181.333333
# Name: energy_per_volume, dtype: float64

# %%
display(doe_mepa_compact['energy_per_volume'].plot.kde(figsize=(16, 8), color='red', alpha=0.4, label='DOE'))
display(epa_compact['energy_per_volume'].plot.kde(figsize=(16, 8), color='green', alpha=0.4, label='EPA'))


# Add title
plt.title('Energy per Volume (kWh/yr/ft3) for Compact Refrigerators')

# Add legend
plt.legend()

# Add average lines
plt.axvline(doe_mepa_compact.energy_per_volume.mean(), color='red', linestyle='dashed', linewidth=1)
plt.axvline(epa_compact.energy_per_volume.mean(), color='green', linestyle='dashed', linewidth=1)
# Out:
# <AxesSubplot: ylabel='Density'>
# <AxesSubplot: ylabel='Density'>

# %%
more_energy_than_doe_average_compact = epa_compact[epa_compact.energy_per_volume > doe_mepa_compact.energy_per_volume.mean()]['Model Number'].count()/epa_compact['Model Number'].count()

print(f"{more_energy_than_doe_average_compact:.2%} of EPA compact refrigerators use more energy per volume than the average DOE compact refrigerator.")
# Out:
# 53.07% of EPA compact refrigerators use more energy per volume than the average DOE compact refrigerator.

# %% [markdown]
# # WHY ARE THERE SO MANY FALSES??
# We were expecting zero falses. Doe is supposed to be a superset of EPA...what's wrong?

# %%
epa.query("exists_in_other_db == True").describe()
# Out:
#        Height (in)   Width (in)  Capacity (Total Volume) (ft3)  \
# count  2033.000000  2033.000000                    2259.000000
# mean     56.342007    27.475603                      13.508145
# std      19.211749     7.875350                       8.530599
# min      17.300000    14.600000                       1.100000
# 25%      34.000000    20.000000                       4.500000
# 50%      66.400000    28.000000                      14.000000
# 75%      70.000000    35.500000                      20.800000
# max      84.500000    65.600000                      31.600000
#
#        Adjusted Volume (ft3)  Annual Energy Use (kWh/yr)  \
# count            2259.000000                 2259.000000
# mean               16.852545                  410.937140
# std                11.128501                  165.958086
# min                 1.500000                  137.000000
# 25%                 5.000000                  266.000000
# 50%                17.800000                  370.000000
# 75%                25.600000                  553.000000
# max                39.900000                  807.000000
#
#        US Federal Standard (kWh/yr)  \
# count                   2259.000000
# mean                     464.070828
# std                      174.497769
# min                      178.000000
# 25%                      307.000000
# 50%                      430.000000
# 75%                      626.000000
# max                      885.000000
#
#        Percent Less Energy Use than US Federal Standard  energy_per_volume  \
# count                                       2259.000000        2259.000000
# mean                                          12.638336          38.636630
# std                                            6.210349          28.100232
# min                                          -25.000000           9.081365
# 25%                                           10.000000          20.307692
# 50%                                           10.000000          24.034091
# 75%                                           11.000000          52.692308
# max                                           48.000000         163.333333
#
#         adj_volume  annual_energy_use
# count  2259.000000        2259.000000
# mean     16.852545         410.937140
# std      11.128501         165.958086
# min       1.500000         137.000000
# 25%       5.000000         266.000000
# 50%      17.800000         370.000000
# 75%      25.600000         553.000000
# max      39.900000         807.000000

# %%
epa.query("exists_in_other_db == False").describe()
# Out:
#        Height (in)   Width (in)  Capacity (Total Volume) (ft3)  \
# count  1411.000000  1411.000000                    1587.000000
# mean     48.191921    23.750602                       9.575362
# std      20.594639     5.924062                       7.370905
# min      14.000000    14.600000                       1.000000
# 25%      33.000000    18.600000                       3.200000
# 50%      35.400000    22.900000                       5.700000
# 75%      67.100000    29.500000                      17.000000
# max      84.500000    42.000000                      29.300000
#
#        Adjusted Volume (ft3)  Annual Energy Use (kWh/yr)  \
# count            1587.000000                 1587.000000
# mean               11.823629                  326.480781
# std                 9.663020                  134.018524
# min                 1.000000                   88.000000
# 25%                 3.300000                  218.000000
# 50%                 8.300000                  300.000000
# 75%                21.000000                  393.000000
# max                37.100000                  782.000000
#
#        US Federal Standard (kWh/yr)  \
# count                   1579.000000
# mean                     374.046865
# std                      143.404505
# min                      168.000000
# 25%                      245.000000
# 50%                      358.000000
# 75%                      440.000000
# max                      838.000000
#
#        Percent Less Energy Use than US Federal Standard  energy_per_volume  \
# count                                       1579.000000        1587.000000
# mean                                          13.405953          48.932601
# std                                            6.827718          34.769169
# min                                          -32.000000           8.324607
# 25%                                           10.000000          21.148610
# 50%                                           11.000000          35.000000
# 75%                                           13.000000          68.125000
# max                                           61.000000         241.000000
#
#         adj_volume  annual_energy_use
# count  1587.000000        1587.000000
# mean     11.823629         326.480781
# std       9.663020         134.018524
# min       1.000000          88.000000
# 25%       3.300000         218.000000
# 50%       8.300000         300.000000
# 75%      21.000000         393.000000
# max      37.100000         782.000000

# %% [markdown]
# - Figure out what the duplicates are. So much of this dataset is duplicate ids. I'm not sure what to do about that.
# - Figuring out any caveats about comparing different fridge types to one another

# %% [markdown]
# ## Efficiency by Refrigerator Design

# %%
epa_all['Type'].unique()
# Out:
# array(['Top Freezer', 'Compact Refrigerator', 'Bottom Freezer', nan,
#        'Compact Cooler', 'Side-by-Side', 'Freezerless and Single Door',
#        'Cooler', 'Upright Freezer', 'Compact', 'Chest Freezer'],
#       dtype=object)
